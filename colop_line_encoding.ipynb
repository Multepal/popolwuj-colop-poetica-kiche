# %% [markdown]
# # Multepal: Colop Poetic K'iche' Edition Line Encoding
# * **Created by:** Aldo Barriente
# * **Date:** 06/25/2021

# %% [markdown]
# ## Set Up

# %%
import re
import xml.etree.ElementTree as et

# %%
text_prefix = "colop_pk_text"
data_in = './source/'
data_out = './encoding_output/'

# %% [markdown]
# ## Importing text

# %%
with open(f'{text_prefix}.txt') as colop_plaintext:
    text = colop_plaintext.readlines()

# %%
text
# Out:
# ["NAB'E\n",
#  '\n',
#  "ARE' UXE' OJER TZIJ WARAL K'ICHE' UB'I'\n",
#  '\n',
#  "Waral xchiqatz'ib'aj wi,\n",
#  "      xchiqatikib'a' wi ojer tzij\n",
#  "utikarib'al,\n",
#  "uxe'nab'al puch ronojel xb'an pa tinamit K'iche'\n",
#  "                                 ramaq' K'iche' winaq.\n",
#  "Are k'ut xchiqak'am wi:\n",
#  "uk'utunisaxik,\n",
#  "uq'alajob'isaxik,\n",
#  'utzijoxik puch\n',
#  "ewaxib'al,\n",
#  "saqirib'al rumal Tz'aqol,\n",
#  "                 B'itol,\n",
#  '                 Alom,\n',
#  "                 K'ajolom kib'i'.\n",
#  "                 Junajpu Wuch',\n",
#  '                 Junajpu Utiw,\n',
#  '                 Saqinim Aq\n',
#  '                         Sis\n',
#  '                 Tepew,\n',
#  "                 Q'ukumatz,\n",
#  "                 Uk'ux Cho,\n",
#  "                 Uk'ux Palo,\n",
#  '                 Ajraxa Laq,\n',
#  "                 Ajraxa Tzel. Chucha'xik,\n",
#  "                              rachb'ixik,\n",
#  '                              rachtzijoxik ri Iyom,\n',
#  '                                              Mamom,\n',
#  '                                              Xpiyakok,\n',
#  "                                              Xmukane, ub'i'.\n",
#  '                                              Matzanel,\n',
#  '                                              Chuqenel,\n',
#  '                                              Kamul Iyom,\n',
#  '                                              Kamul Mamom.\n',
#  "                                              Chucha'xik pa K'iche' tzij.\n",
#  '                                                \n',
#  'Ta xkitzijoj ronojel\n',
#  "ruk' xkib'an chik \n",
#  "chi saqil k'olem,\n",
#  '    saqil tzij.\n',
#  "Wa'e xchiqatz'ib'aj chi upam chik\n",
#  "                        uch'ab'al Dias,\n",
#  '                        pa christianoil chik.\n',
#  "xchiqelesaj rumal maja b'i chik ilb'al re Popa Wuj,\n",
#  "                                ilb'al saq petenaq ch'aqa palo\n",
#  "                                       utzijoxik qamujib'al,\n",
#  "                                ilb'al saq k'aslem'; chucha'xik.\n",
#  "K'o nab'e wujil,\n",
#  "ojer tzib'am puch,\n",
#  'xa ewal uwach ilol re,\n',
#  "              b'isol re.\n",
#  "Nim upe'oxik,\n",
#  'utzijoxik puch,\n',
#  "ta chi k'is tz'uq ronojel kaj,\n",
#  '                          ulew:\n',
#  "ukaj tz'uquxik,\n",
#  'ukaj xukutaxik,\n',
#  '     retaxik;\n',
#  "ukaj che'xik,\n",
#  "umej k'a'maxik,\n",
#  "uyuq k'a'maxik upa kaj,\n",
#  '               upa ulew;\n',
#  "kaj tz'uq,\n",
#  "kaj xukut, chucha'xik rumal ri Tz'aqol,\n",
#  "                               B'itol;\n",
#  'Uchuch,\n',
#  "Uqajaw k'aslem,\n",
#  '       Winaqirem:\n',
#  "Ab'anel,\n",
#  "K'uxlanel;\n",
#  'Alay rech,\n',
#  "K'uxlay rech saqil\n",
#  '             amaqil;\n',
#  '             saqil al,\n',
#  "             saqil k'ajol;\n",
#  "Ajb'is,\n",
#  "Ajna'oj chi rech ronojel a ta k'ol wi kaj-ulew,\n",
#  '                                      cho-palo.\n',
#  '\n',
#  "ARE UTZIJOXIK WA'E\n",
#  '\n',
#  "k'akatz'ininoq,\n",
#  "k'akachamamoq,\n",
#  "   katz'inonik,\n",
#  "k'akasilanik,\n",
#  "k'akalolinik,\n",
#  '   katolona puch upa kaj.\n',
#  '\n',
#  "Wa'e k'ute nab'e tzij,\n",
#  "           nab'e uchan:\n",
#  "maja' b'i oq\n",
#  '      jun winaq,\n',
#  '      jun chikop,\n',
#  "      tz'ikin,\n",
#  '      kar,\n',
#  '      tap,\n',
#  "      che',\n",
#  "      ab'aj,\n",
#  '      jul,\n',
#  '      siwan,\n',
#  "      k'im,\n",
#  "      k'ichelaj,\n",
#  "xa utukel kaj k'olik.\n",
#  "Mawi q'alaj uwach ulew,\n",
#  'xa utukel remanik palo\n',
#  '            upa kaj, ronojel.\n',
#  "Maja' b'i naki la' kamolob'ik,\n",
#  "                   k'akotzob'ik,\n",
#  "                   jun ta kasilob'ik,\n",
#  "kumal kab'an taj,\n",
#  "k'akotz kab'an taj pa kaj:\n",
#  "xa ma k'o wi naki la' k'olik yakalik,\n",
#  "xa remanik ja',\n",
#  "xa li'anik palo,\n",
#  'xa utukel remanik,\n',
#  "xa ma k'o wi naki la' lo k'olik;\n",
#  'xa kachamanik,\n',
#  "   katz'ininik chi q'equ'm,\n",
#  "               chi aq'ab'.\n",
#  '\n',
#  "Xa utukel ri Tz'aqol,\n",
#  "             B'itol,\n",
#  '             Tepew,\n',
#  "             Q'ukumatz,\n",
#  '             e Alom,\n',
#  "             e K'ajolom k'o pa ja'\n",
#  "             saqtetoj e k'o wi.\n",
#  "E muqutal pa q'uq',\n",
#  '          pa raxon;\n',
#  "are ub'inam wi ri Q'ukumatz.\n",
#  'E nimaq etamanel,\n',
#  "e nimaq ajna'oj chi kik'oje'ik.\n",
#  "K'eje k'ut xax k'o wi ri kaj\n",
#  "k'o wi nay puch Uk'ux Kaj,\n",
#  "are' ub'i' ri kab'awil. Chuchaxik.\n",
#  "Ta xpe k'ut utzij waral,\n",
#  "xul kuk' ri Tepew,\n",
#  "            Q'ukumatz waral chi q'equmal\n",
#  "                            chi aq'ab'al;\n",
#  "xch'aw ruk' ri Tepew,\n",
#  "               Q'ukumatz.\n",
#  "Xecha' k'ut:\n",
#  "ta xena'ojinik,\n",
#  "ta xeb'isonik,\n",
#  "   xeriqo kib',\n",
#  '   xkikuch kitzij,\n',
#  "           kina'oj;\n",
#  "ta xq'alaj,\n",
#  "ta xkik'uxlaj kib' xe' wi saq,\n",
#  "ta xq'alaj puch winaq;\n",
#  "ta xkina'ojij utz'uqik,\n",
#  "              uwinaqirik che',\n",
#  "                         k'a'm,\n",
#  "              utz'uquxik puch k'aslem\n",
#  '                              winaqirem\n',
#  "chi q'equmal,\n",
#  "chi aq'ab'al; rumal ri Uk'ux Kaj, Jun Raqan ub'i;\n",
#  "                       Kaqulja Jun Raqan, nab'e;\n",
#  "                       ukab' k'ut, Ch'ipi Kaqulja;\n",
#  '                       rox chik, Raxa Kaqulja;\n',
#  "  chi e k'u oxib' ri', Uk'ux Kaj.\n",
#  '\n',
#  "Ta xe'ul kuk' ri Tepew,\n",
#  "                 Q'ukumatz,\n",
#  "ta xna'ojixik saq k'aslem:\n",
#  '-Jupa cha ta chawaxoq,\n',
#  '          ta saqiroq puch?\n',
#  'Apachinaq tzuqul,\n',
#  "          k'ool?\n",
#  'Ta chuxoq!\n',
#  'Kixnojin taj:\n',
#  "Are ri ja' chel taj!,\n",
#  "           chi jama' taj!\n",
#  'Chiwinaqir wa ulew,\n',
#  "              ulaqel ta k'u rib'\n",
#  "Ch'ata k'ut.\n",
#  'Ta chawaxoq,\n',
#  'ta saqiroq kaj,\n',
#  '           ulew!\n',
#  "Mata k'ut uq'ijilab'al,\n",
#  "          uq'ala'ib'al ri qatz'aq\n",
#  "                       ri qab'it.\n",
#  "Ta winaqiroq: winaq tz'aq,\n",
#  "              winaq b'it! Xecha' k'ut.\n",
#  '\n',
#  "TA XWINAQIR K'U RI ULEW KUMAL\n",
#  '\n',
#  "Xa kitzij xk'oje wi uwinaqirik.\n",
#  'Chiwinaqir ulew:\n',
#  '-Ulew! Xecha.\n',
#  "Lib'aj chi' xwinaqirik:\n",
#  "k'eje ri xa ta sutz',\n",
#  '         xa mayul uwinaqirik,\n',
#  "           chi k'u pupuje'ik.\n",
#  "Ta xtape pa ja' ri juyub',\n",
#  "     jusuk' nima'q juyub' xuxik.\n",
#  'Xa kinawal,\n',
#  "xa kipus xb'anataj wi,\n",
#  "una'ojixik juyub',\n",
#  "           taq'aj,\n",
#  "jusuk' rach winaqirik uq'isisil,\n",
#  '                      upachÃ¤jil uwach.\n',
#  "K'eje k'ut xkikot wi ri Q'ukumatz:\n",
#  "-Utz mixatulik at Uk'ux Kaj,\n",
#  '               at Junraqan,\n',
#  "               at puch Ch'ipi Kaqulja,\n",
#  '                       Raxa Kaqulja!\n',
#  'Xchutzinik qatzak,\n',
#  "           qab'it. Xecha' k'ut.\n",
#  "Nab'e k'ut xwinaqir ulew,\n",
#  "                    juyub'-taq'aj;\n",
#  "xch'ob'och'ox ub'e ja':\n",
#  "xb'inije'ik k'ole je raqan xo'l taq juyub'\n",
#  "xa ch'ob'ol chik xek'oje wi ja,\n",
#  "ta xk'utunije'ik nima'q juyub'.\n",
#  "K'eje k'ut uwinaqirik ulew ri,\n",
#  "ta xwinaqirik kumal ri Uk'ux Kaj,\n",
#  "                       Uk'ux Ulew. Ke'ucha'xik.\n",
#  '        \n',
#  "Ri' k'ut e nab'e xkinojij,\n",
#  "xk'olo wi ri kaj,\n",
#  "xk'olo nay puch ulew chi upam ja'.\n",
#  "K'eje k'ut uno'jixik ri,\n",
#  "ta xkino'jij,\n",
#  "ta xkib'isoj rutzinik,\n",
#  "             ub'anatajik, kumal.\n",
#  "Ta xkino'jij chik uchikopil juyub',\n",
#  "                  chajal re ki'chelaj\n",
#  "                  ronojel uwinaqil juyub':\n",
#  'ri kyej,\n',
#  "tz'ikin,\n",
#  'koj,\n',
#  "b'alam,\n",
#  'kumatz,\n',
#  'sochoj,\n',
#  'kanti,\n',
#  "chajal k'a'm.\n",
#  "Kacha' ri Alom,\n",
#  "          K'ajolom:\n",
#  '-Xa pa chi lolinik,\n',
#  "ma xa on chi tz'ininik uxe' che',\n",
#  "                            k'a'm?\n",
#  "K'ate utz chi k'oje chajal re. Xecha' k'ut.\n",
#  'Ta xkinojij,\n',
#  '   xkitzijoj puch;\n',
#  "jusuk' xwinaqir kej,\n",
#  "                tz'ikin.\n",
#  "Ta xkisipaj k'ut rochoch kej,\n",
#  "                         tz'ikin:\n",
#  "-At kej pa b'e ja',\n",
#  '        pa siwan katwar wi;\n',
#  "        waral katk'oje' wi;\n",
#  "        pa k'im,\n",
#  '        pa saqul;\n',
#  "        pa k'echelaj kipoqo wi iwib'!\n",
#  "Kajkaj ib'inib'al,\n",
#  "       ichakab'al, chuxik! Xe'ucha'xik.\n",
#  "Ta xkich'ik k'ut kochoch ch'uti tz'ikin,\n",
#  "                         nima tz'ikin:\n",
#  "-Ix, ix tz'ikin chuwi che',\n",
#  "                chuwi k'a'm kixochochin wi,\n",
#  "                            kixja'in wi!\n",
#  "                chi ri' kixpoq wi,\n",
#  "                        kixk'iritaj wi\n",
#  "                chuq'ab' che',\n",
#  "                chuq'ab' k'a'm! Xe'ucha'xik kyej,\n",
#  "                                            tz'ikin.\n",
#  "Ta xkib'ano\n",
#  "   kib'anoj,\n",
#  "ronojel xuk'amo uwarab'al,\n",
#  "                uyakalib'al.\n",
#  "K'eje k'ut kochoch wi chikop ri ulew xuya'o Alom,\n",
#  "                                            K'ajolom;\n",
#  'xutzininaq chik ronojel ri kej,\n',
#  "                           tz'ikin.\n",
#  '\n',
#  "Ta xe'uchax chi k'ut ri kej,\n",
#  "                        tz'ikin; rumal Tz'aqol,\n",
#  "                                       B'itol,\n",
#  '                                       Alom,\n',
#  "                                       K'ajolom:\n",
#  "-Kixch'awoq,\n",
#  "Kixsik'inoq!\n",
#  'mixyonolikinik,\n',
#  "mixsik'inik!\n",
#  "Kixch'awajetaj chi jujunal,\n",
#  "               chu jutaq ch'ob'il,\n",
#  '               chi jutaq molajil!\n',
#  "Xe'ucha'xik ri kej,\n",
#  "               tz'ikin,\n",
#  '               koj,\n',
#  "               b'alam,\n",
#  '               kumatz.\n',
#  "-Chib'ij na k'ut ri qab'i',\n",
#  'Kojiqajarisaj, oj ichuch,\n',
#  '               oj iqajaw!\n',
#  "Kixcha' b'a na k'ut:\n",
#  '   Junraqan,\n',
#  "   Ch'ipi Kaqulja,\n",
#  '   Raxa Kaqulja;\n',
#  "   Uk'ux Kaj,\n",
#  "   Uk'ux Ulew;\n",
#  "   Tz'aqol,\n",
#  "   B'itol;\n",
#  '   Alom,\n',
#  "   K'ajolom.\n",
#  "   Kixch'awoq,\n",
#  "   Kojiq'ijila'! Xe'ucha'xik.\n",
#  '\n',
#  "Ma k'u xutzinik\n",
#  "       xech'awik k'eje ta ri winaq.\n",
#  'Xa kewachelajik,\n',
#  "xa kek'aralajik,\n",
#  'xa kewojonik;\n',
#  "mawi xwachinik uwach kich'ab'al.\n",
#  "Jalajoj xkoq'ib'ej chi kijujunal.\n",
#  "Ta xkita ri Tz'aqol,\n",
#  "            B'itol,\n",
#  'mawi mixutzinik,\n',
#  "     mixech'awik.\n",
#  "Xecha' chik chi kib'il kib':\n",
#  "-Mawi mixutzin ub'ixik qab'i';\n",
#  "rumal oj kajtz'aq,\n",
#  "      oj pu kajb'it: mawi utz!-\n",
#  "Xecha' chik chi kib'il kib' ri Alom,\n",
#  "                               K'ajolom.\n",
#  "Xe'uchax k'ut:\n",
#  'Xa kixjalatajik rumal mawi mixutzinik,\n',
#  "                      mawi mixixch'awik.\n",
#  "Mi k'u xqajal qatzij;\n",
#  "              iwecha',\n",
#  "              ik'uxun;\n",
#  "              iwarab'al,\n",
#  "              iyakalib'al;\n",
#  "Ri wech wi mixe'uxik siwan,\n",
#  "           k'echelaj rumal mawi xutzin qaq'ijiloxik,\n",
#  "                           mawi ixsik'iy qe.\n",
#  "K'a k'o,\n",
#  "k'o wi lo q'ijilonel,\n",
#  "          nimanel chi qab'an chik!\n",
#  "Xa chik'am ipatan:\n",
#  "xa ityo'jil chikach'ik.\n",
#  "Ta chuxoq! Are k'ut chipatanij. Xe'ucha'xik.\n",
#  "Ta xepixab'axik ch'uti chikop,\n",
#  "                nima chikop k'o chuwach ulew.\n",
#  "Ta xraj k'u kitij chik kiq'ij;\n",
#  "   xraj kitijtob'ej chik,\n",
#  "   xraj pu kinuk' chik q'ijilab'al.\n",
#  "Xa ma xkita wi kich'ab'al chi kib'il kib'.\n",
#  "Xa ma xnawachir wi k'ut,\n",
#  "xa ma b'anataj wi puch.\n",
#  "K'eje k'ut xech'akataj wi kityo'jil.\n",
#  'Xkipatanij: xetiyik,\n',
#  "            xekamisaxik ri chikop k'o waral chuwach ulew.\n",
#  '\n',
#  "K'EJE K'UT UTIJTOB'EXIK CHIK WINAQ TZ'AQ,\n",
#  "                             WINAQ B'IT KUMAL Tz'aqol\n",
#  "                                              B'itol;\n",
#  '                                              Alom,\n',
#  "                                              K'ajolom;\n",
#  '\n',
#  "-Xa k'u tija chik\n",
#  'mixyopij rawexik ,\n',
#  '         usaqirik?\n',
#  "Qab'ana' tzuqul qe,\n",
#  "         k'ool qe.\n",
#  "Ju pa cha ta kojsik'ixoq,\n",
#  "          ta kojnab'ax puch chuwach ulew?\n",
#  "Mixqatijo chi rech ri nab'e qatz'aq,\n",
#  "                            qab'it.\n",
#  "Mawi mixutzinik qaq'ijiloxik,\n",
#  "                qaq'alajixik puch kumal.\n",
#  "K'eje k'ut qatija wi ub'anik ajnim,\n",
#  "                             ajxob';\n",
#  '                             tzuqul,\n',
#  "                             k'ool! Xecha'.\n",
#  "Ta utz'aqik k'ut,\n",
#  "   ub'anik puch ulew,\n",
#  "                xoq'o'l utyo'jil xkib'ano.\n",
#  'Ma ku utz xkilo:\n',
#  'xa chi yojomanik,\n',
#  "xa tzub'ulik,\n",
#  "xa neb'elik,\n",
#  "xa lub'anik,\n",
#  'xa wulanik,\n',
#  "xa pu chi'umarik.\n",
#  "Mawi chi k'olol ujolom,\n",
#  "xa jun b'enaq wi uwach,\n",
#  "xa ku'l uwach;\n",
#  'mawi chi mukun chi rij.\n',
#  "Chi ch'aw nab'e maja b'i una'oj.\n",
#  "xa jusuk' chi'umar pa ja'.\n",
#  "-Mawi k'o-; xecha' chi k'u ri Ajtz'aq,\n",
#  "                              Ajb'it.\n",
#  "Qaw achlab'eq!\n",
#  'Ta chuxoq!\n',
#  "Xa lab'e mawi chib'inik,\n",
#  "         ma pu chipoq'otajik.\n",
#  'Ta chuxoq!\n',
#  "Xa una'oj chiri'! Xecha'.\n",
#  "Ta xkiyoj k'ut,\n",
#  "   xkiyoq' chik ri kitz'aq,\n",
#  "                   kib'it.\n",
#  "Xecha' chi k'ut:\n",
#  "-Jupa cha ki chiqab'ano?\n",
#  'Chutzin ta wi,\n',
#  'chinawachir ta wi\n',
#  "q'ijiloy qech,\n",
#  "  siq'iy qech? Xecha' ta xkina'ojij chik:\n",
#  "-Xa qab'ij chi ke Xpiyakok,\n",
#  '                  Xmukane;\n',
#  "                  Junajpu Wuch',\n",
#  '                  Junajpu Utiw;\n',
#  "kitija chik uq'ijixik,\n",
#  "            ub'itaxik-.\n",
#  "Xe'uchan ki kib' Ajtz'aq,\n",
#  "                 Ajb'it.\n",
#  "Ta xkib'ij k'ut chi re Xpiyakok,\n",
#  '                       Xmukane.\n',
#  '\n',
#  "K'ATE K'UT UB'IXIK RI' CHI KECH RI E NIK'WACHINEL,\n",
#  "Rati't Q'ij,\n",
#  "Rati't Saq, ke'ucha'xik kumal ri Tz'aqol,\n",
#  "                                 B'itol.\n",
#  "Are kib'i' ri Xpiyakok,\n",
#  '              Xmukane.\n',
#  "Xecha' k'u ri Juraqan ruk' Tepew,\n",
#  "                           Q'ukumatz;\n",
#  "ta xkib'ij chi rech ajq'ij,\n",
#  "                    ajb'it,\n",
#  "                    e nik'wachinel:\n",
#  "-Xa k'ulu\n",
#  "xa pu churiqo che ta chik chiqawinaq-b'itoj,\n",
#  "                          chiqawinaq-tz'aqoj ta chik tzuqul,\n",
#  "                                                     k'ool,\n",
#  "kojsik'ix taj,\n",
#  "kojnab'ax taj puch.\n",
#  "Katok ta k'ut pa tzij Iyom,\n",
#  '                      Mamom;\n',
#  "                      qati't\n",
#  '                      qamam;\n',
#  '                      Xpiyakok,\n',
#  '                      Xmukane:\n',
#  'cha taj ta chawaxoq,\n',
#  '        ta saqiroq:\n',
#  "qasik'ixik,\n",
#  "qatoq'exik,\n",
#  "qanab'axik rumal winaq tz'aq,\n",
#  "                 winaq b'it,\n",
#  '                 winaq poy,\n',
#  '                 winaq anom;\n',
#  'cha ta chuxoq!\n',
#  "Chik'utun ib'i' Junajpu Wuch',\n",
#  '                Junajpu Utiw;\n',
#  '                Kamul Alom,\n',
#  "                Kamul K'ajolom;\n",
#  '                Nim Aq,\n',
#  '                Nima Sis,\n',
#  "                Ajk'uwal,\n",
#  '                Ajyamanik,\n',
#  "                Ajch'ut,\n",
#  "                Ajtz'alam,\n",
#  '                Ajraxa laq,\n',
#  '                Ajraxa tzel,\n',
#  "                Ajq'ol,\n",
#  '                Ajtoltekat,\n',
#  "                Rati't Q'ij,\n",
#  "                Rati't Saq; kixucha'xik rumal qatz'aq,\n",
#  "                                              qab 'it!\n",
#  'Chimala chi ixim,\n',
#  "        chi tz'ite':\n",
#  "xa chib'anatajik,\n",
#  'xa pu chel apanoq,\n',
#  "chiq'ajaj,\n",
#  "chik'ak'otaj puch uchi',\n",
#  "                  uwach che'-. Xe'ucha'xik e ajq'ij.\n",
#  "K'ate puch uqajik,\n",
#  "           uq'ijiloxik ri xmalik chi ixim,\n",
#  "                                 chi tz'ite':\n",
#  "-Q'ij,\n",
#  "b'it! Xecha' k'u ri jun ati't,\n",
#  "                    jun mama' chi kech.\n",
#  "Are ri mama' are ajtz'ite', Xpiyakok ub'i';\n",
#  "are k'u ri ati't ajq'ij,\n",
#  "                 ajb'it chi raqan, Xmukane ub'i'.\n",
#  "Xecha' k'ut ta xkitikib'a' q'ij:\n",
#  "-Xa chuk'ulu,\n",
#  'xa pu churiqo;\n',
#  "chab'ij,\n",
#  'kuta qaxikin;\n',
#  "kach'awik,\n",
#  'katzijon taj.\n',
#  "Xa chuk'ulu ri che' chajawaxik,\n",
#  "                    chik'otox puch kumal Ajtz'aq,\n",
#  "                                         Ajb'it.\n",
#  'We are tzuqul,\n',
#  "       k'ool;\n",
#  'ta chawaxoq,\n',
#  'ta saqiroq!\n',
#  'at ixim,\n',
#  "at tz'ite';\n",
#  "at q'ij,\n",
#  "at b'it katchokonik,\n",
#  "        kattaqen taj-. Xcha' chi re ixim,\n",
#  "                                    tz'ite',\n",
#  "                                    q'ij,\n",
#  "                                    b'it.\n",
#  "-Katk'ix la uloq at Uk'ux Kaj,\n",
#  "ma qajisaj uchi',\n",
#  '           uwach Tepew,\n',
#  "                 Q'ukumatz-. Xecha' ta xkib'ij k'ut usuk'ulikil\n",
#  'Utz are chuxik ri ipoy,\n',
#  "                  ajam che' chich'awik,\n",
#  "                            chitzijon b'a la chuwach ulew.\n",
#  "Ta chuxoq! Xecha' k'ut.\n",
#  "Ta xkib'ij jusuk' xb'anik poy,\n",
#  "                          ajam che'.\n",
#  'Xewinaq-wachinik,\n',
#  'xewinaq-tzijonik puch;\n',
#  "are' winaqil uwach ulew xe'uxik,\n",
#  "xepoq'ik,\n",
#  "xeme'alanik,\n",
#  "xek'ajolanik ri poy,\n",
#  "                ajam che'.\n",
#  "Ma k'u ja b'i kik'ux,\n",
#  "ma pu ja b'i kina'oj;\n",
#  "mawi na'tal kajtz'aq,\n",
#  "            kajb'it.\n",
#  "Xa loq' xeb'inik,\n",
#  '        xechakanik.\n',
#  "Mawi xkina'taj chik ri Uk'ux Kaj.\n",
#  "K'eje k'ut xepaj chiri':\n",
#  "xa utijtob'exik,\n",
#  "xa pu uwab'ab'exik chi winaq.\n",
#  "Kechaw nab'e;\n",
#  "xa chaqi'j kiwach,\n",
#  'mana sonol kaqan,\n',
#  "           kiq'ab';\n",
#  "maja b'i kikik'el,\n",
#  '         kikomajil ,\n',
#  "maja b'i kitiqowal,\n",
#  "         kikab'chijal.\n",
#  "Chaqi'j kotz,\n",
#  "k'oj kiwach.\n",
#  'Kapichipoj kaqan,\n',
#  "           kiq'ab';\n",
#  "Kayeyoj kityo'jil.\n",
#  "K'eje k'ut mawi xena'w chi ri' chuwach Tz'aqol,\n",
#  "                                       B'itol,\n",
#  '                                       Alay Qech,\n',
#  "                                       K'uxla'y Qech.\n",
#  "E nab'e tzatz chi winaq xe'uxik waral chuwach ulew.\n",
#  '\n',
#  "K'ATE K'UT KIK'ISIK CHIK,\n",
#  '\n',
#  "kima'ixik,\n",
#  "kik'utuxik puch;\n",
#  'xekamisax chik poy,\n',
#  "               ajam che'.\n",
#  "Ta xna'ojix kib'utik rumal Uk'ux Kaj;\n",
#  "nima b'utik xb'anik:\n",
#  'xpe pa kiwi ri e poy,\n',
#  "               e ajam che'.\n",
#  "Tz'ite' utyo'jil ri achij ta xajaxik rumal Tz'aqol,\n",
#  "                                           B'itol;\n",
#  "ixoq, sib'ak k'ut utyo'jil ixoq xraj okik rumal Tz'aqol,\n",
#  "                                                B'itol.\n",
#  "Mawi xena'wik,\n",
#  "ma pu xech'awik chuwach kajtz'aq,\n",
#  "                        kajb'it;\n",
#  "                        b'anol ke,\n",
#  '                        winaqirisay kech.\n',
#  "K'eje k'ut kikamisaxik,\n",
#  "           xeb'utik:\n",
#  "xpe nima q'ol chila' chi kaj,\n",
#  "xpe k'otk'owach ub'i' xk'otin uloq ub'aq' kiwach;\n",
#  "xepe kamalotz' xqupin ula kijolom.\n",
#  "xpe kotzb'alam xti'o kityo'jil.\n",
#  "xpe tukumb'alam xtukuwik,\n",
#  "                xkichowik kib'aqil,\n",
#  "                          kib'ochil.\n",
#  'Xqajixik,\n',
#  "xmuchulixik kib'aqil;\n",
#  "k'ajisab'al kiwach rumal mawi kinawik chuwach kichuch,\n",
#  '                                      chuwach puch kikajaw;\n',
#  "                                      Ri Uk'ux Kaj,\n",
#  "                                      Juraqan ub'i'.\n",
#  "Kumal xq'equ'marik uwach ulew:\n",
#  "xtikarik q'eqal jab',\n",
#  "q'ijil jab',\n",
#  "aqab'al jab'\n",
#  "xok ula' ch'uti chikop,\n",
#  '         nima chikop.\n',
#  "xkut kiwach rumal che',\n",
#  "                  ab'aj.\n",
#  "Xch'awik ronojel kiq'eb'al,\n",
#  '                 kixot,\n',
#  '                 kilaq,\n',
#  "                 kib'o'j,\n",
#  "                 kitz'i',\n",
#  "                 kika';\n",
#  "jaruj pa' la ronojel xkutu kiwach.\n",
#  "-k'ax xib'an chi qe:\n",
#  'xojitiyo,\n',
#  "ix chi k'ut\n",
#  "xkixqati' chik! Xcha' ri kitz'i'\n",
#  "                         kak' chi kech.\n",
#  "Are k'u ri ka':\n",
#  "- xojk'ok'onik iwumal juta q'ij,\n",
#  "                      juta q'ij;\n",
#  "                      xq'ek,\n",
#  '                      saqirik;\n',
#  "amaq'el joli,\n",
#  '        joli;\n',
#  "        juk'i,\n",
#  "        juk'i qawach iwumal.\n",
#  "Are ta nab'e qapatan chi wach\n",
#  "ix ta na winaq wakamik k'ut\n",
#  "xchitij qachuqab':\n",
#  "xchiqake'j,\n",
#  "xchiqajok' puch ityo'jil! Xcha' ri kika' chi ke.\n",
#  "Are k'u ri kitz'i' xcha' chik ta xch'awik:\n",
#  "-Naki pa rumal mawi chiya' qawa?\n",
#  'xa kojmukunik,\n',
#  'xa pu kojikuxij uloq,\n',
#  '      kojitzaq pu uloq;\n',
#  "yakal ub'i qache'el iwumal ta kixwa'ik.\n",
#  "Xere kojiwucha'aj wi,\n",
#  "mawi kojch'awik.\n",
#  "Mata k'u mixojkamik iwumal!\n",
#  '-Jupa cha mawi mixixnawik\n',
#  "xixnaw ta k'ut;\n",
#  "chi wij ta k'ut xojsach wi.\n",
#  "Wakamik k'ut xchitij qab'aq k'o pa qachi':\n",
#  "xkixqati'o! Xecha' ri tz'i' chi ke ta xkut kiwach.\n",
#  '\n',
#  "Are chi k'u ri kixot,\n",
#  "               kib'o'j xch'aw chik chi ke:\n",
#  "- K'ax wa xib'an chi qe:\n",
#  "xaq qachi',\n",
#  'xaq qawach;\n',
#  "amaq'el ojtzaqal chuwi q'aq'\n",
#  "kojik'ato.\n",
#  "Mawi k'ax xqana'o?\n",
#  "xchitij k'ut: xkixqaporoj! Xcha' ri kib'o'j.\n",
#  'Ronojel xkutu kiwach.\n',
#  "Are ri ab'aj,\n",
#  "    ri kixk'ub' chitaninik chipe pa q'aq',\n",
#  'taqal chi kijolom.\n',
#  "K'ax xb'an chi ke.\n",
#  "Anilab'ik\n",
#  "kemalmalijab' chik;\n",
#  "keraj aq'anik chuwi ja,\n",
#  '       xa chi wulij ja ketzaq uloq;\n',
#  "keraj aq'an chuwi che',\n",
#  "      kech'akix uloq rumal che'.\n",
#  'Keraj ok pa jul,\n',
#  '      xa chiyuch jul chi kiwach.\n',
#  "K'eje k'ut ukayojik winaq tz'aq,\n",
#  "                    winaq b'it,\n",
#  'e tzixel,\n',
#  'e tzalatzoxel chi winaq.\n',
#  "Xma'ixik,\n",
#  "xk'utuxik kichi',\n",
#  '          kiwach konojel.\n',
#  '\n',
#  "Xcha' k'ut are retal ri k'oy k'o pa k'echelaj wakamik.\n",
#  "Are xk'oje wi retal rumal xa che' kityo'jil xkojik rumal Ajtz'aq,\n",
#  "                                                         Ajb'it.\n",
#  "Are k'u ri k'oy keje ri winaq chiwachinik,\n",
#  "retal ju le' winaq tz'aq,\n",
#  "             winaq b'it;\n",
#  'xa poy,\n',
#  "xa pu ajam che'.\n",
#  '\n',
#  "UKAB'\n",
#  '\n',
#  "ARE K'UT XA JUB'IQ' SAQNATANOJ UWACH ULEW,\n",
#  "                    MAJA B'I Q'IJ\n",
#  '\n',
#  "Jun k'ut kunimarisaj rib' Wuqub' Kaq'ix, ub'i'.\n",
#  "K'o nab'e kaj,\n",
#  '          ulew,\n',
#  "xa kamoymot uwach q'ij,\n",
#  "                  ik'.\n",
#  "Kacha' k'u ri':\n",
#  "Xawi xere usaqetal winaq ri xb'utik,\n",
#  "keje ri nawal winaq uk'oje'ik;\n",
#  "-In nim kik'oje chik chuwi winaq tzaq,\n",
#  "                           winaq b'it:\n",
#  "in qu'ij,\n",
#  'in pu usaq,\n',
#  "in nay pu rik'il; ta chuxoq!\n",
#  'Nim nusaqil,\n',
#  "in b'inib'al,\n",
#  "in pu chakab'al rumal winaq!\n",
#  "Rumal puwaq ub'aq nuwach xa katiltotik chi yamanik,\n",
#  "                                           raxa k'uwal;\n",
#  "nay pu we rax kawakoj chi ab'aj keje ri uwa kaj.\n",
#  "Are k'u ri nutza'm saq julujuj chi naj k'eje ri ik'.\n",
#  "Puwaq k'ut nuq'alib'al:\n",
#  "k'a saq pak'e uwach ulew ta kinel uloq chuwach nuq'alib'al.\n",
#  "K'eje k'ut in q'ij wi,\n",
#  "           in pu ik' rumal saqil al,\n",
#  "                           saqil k'ajol.\n",
#  'Ta chuxoq!\n',
#  "Rumal chi naj kopon wi nuwach! Cha' ri Wuqub' Kak'ix.\n",
#  "Ma k'u qitzij are ta q'ij ri Wuqub' Kak'ix.\n",
#  "Xere kunimarisaj rib',\n",
#  "                 ri uxik',\n",
#  '                    upuwaq.\n',
#  "Xere k'ut tokol wi uwach ri chi kub'e wi;\n",
#  "mana ronojel ta uxe' kaj kopon wi uwach.\n",
#  "Maja k'ut k'i kiloq uwach q'ij,\n",
#  "                          ik',\n",
#  "                          ch'umil,\n",
#  "maja'oq kasaqiroq.\n",
#  "K'eje k'ut kukob'isaj wi rib' ri Wuqub' Kak'ix chi q'ijil,\n",
#  "                                               chi ik'il.\n",
#  "Xa maja chi k'utunoq,\n",
#  "chi q'alajob'oq usaqil q'ij,\n",
#  "                       ik'.\n",
#  'Xa xurayij nimal,\n',
#  "                ik'owen.\n",
#  "Are ta xb'anik b'utik kumal poy\n",
#  "                            ajam che'.\n",
#  '\n',
#  "K'EJE K'UT XCHIQAB'IJ CHIK TA XKAMIK WUQUB' KAK'IX,\n",
#  '\n',
#  'ta xchakatajik,\n',
#  "ta xb'anatajik winaq rumal Ajtz'aq,\n",
#  "                           Ajb'it.\n",
#  "Wa'e uxe' uch'akatajik,\n",
#  "          uyiqoxik chi puch uq'ij Wuqub' Kak'ix kumal ka'ib'\n",
#  "k'ajolab',\n",
#  "Junajpu ub'i' jun,\n",
#  "Xb'alanke ub'i' ukab'.\n",
#  "Xawi e kab'awil.\n",
#  "Rumal itzel xkilo ri nimarisay rib'\n",
#  "xraj ub'an chuwach Uk'ux Kaj.\n",
#  "Xcha' ku ri k'ajolab':\n",
#  '- Mawi utz ta chuxoq.\n',
#  "Mawi chik'ase winaq waral chuwach ulew.\n",
#  "K'eje k'ut chiqatij uwub'axik chuwi recha';\n",
#  "chiqawub'aj wi chiri',\n",
#  "chiqakoj wi uyab'!\n",
#  "Tak'isoq uq'inomal,\n",
#  '         uxit,\n',
#  '         upuwaq,\n',
#  "         uk'uwal,\n",
#  "         uyamanik ri kuk'akab'ej.\n",
#  "K'eje k'ut chub'ano ronojel winaq,\n",
#  "mawi are chiwinaqir wi q'aq'al ri xa puwaq.\n",
#  "Ta chuxoq-. Xecha' ri k'ajolab'\n",
#  "jujun chi ub' kitelen kikab'ichal.\n",
#  '\n',
#  "Are k'u ri Wuqub' Kak'ix e ka'ib' uk'ajol:\n",
#  "are nab'e al ri Sipakna,\n",
#  "ukab' al chi k'ut ri Kab'raqan;\n",
#  "Chimalmat k'ut ub'i' kichuch,\n",
#  "                     rixoqil ri Wuqub' Kak'ix.\n",
#  '\n',
#  "Are k'u ri Sipakna are chi re chaaj ri nimaq juyub':\n",
#  "ri Chi q'aq',\n",
#  '   Junajpu,\n',
#  "   Pek ul ya',\n",
#  '   Xkanul,\n',
#  "   Makamob',\n",
#  "   Julisnab'. Chucha'xik ub'i' juyub' xk'olik ta chisaqirik.\n",
#  "Xa jun aq'ab' chiwinaqirik rumal Sipakna.\n",
#  '\n',
#  "Are ri chi k'u ri Kab'raqan chisilab' juyub' rumal,\n",
#  "chineb'owik ch'uti juyub',\n",
#  "            nima juyub' rumal.\n",
#  "Xawi keje nimarisab'al kib' xkib'ano uk'ajol Wuqub' Kak'ix.\n",
#  "- In wa', in q'ij! Xcha' Wuqub' Kak'ix.\n",
#  "- In wa', in b'anol ulew! Xcha' ri Sipakna.\n",
#  "- In chi k'ut chinkiyow kaj,\n",
#  "              chinwulij ronojel ulew! Xcha' ri Kab'raqan.\n",
#  "Xawi uk'ajol Wuqub' Kak'ix,\n",
#  "xawi chi ri' xkik'am wi kinimal,\n",
#  '     chi rij kikajaw.\n',
#  "Are k'ut itzel xkil ri k'ajolab'.\n",
#  "Maja chib'antajoq qa nab'e chuch,\n",
#  "                  qa nab'e qajaw.\n",
#  "K'eje k'ut xna'ojix wi kikamik,\n",
#  "                       kisachik kumal k'ajolab'.\n",
#  '\n',
#  "Wa'e k'ute uwub'axik Wuqub' Kak'ix kumal ka'ib' k'ajolab':\n",
#  "xchiqab'ij kich'akatajik chi kijujunal ri nimarisaj rib'.\n",
#  "Are ri Wuqub' Kak'ix jun nima che' ri tapa'l,\n",
#  "are k'u recha' ri Wuqub' Kak'ix.\n",
#  "Are chu lo ri uwach tapa'l,\n",
#  "chaqan chuwi che' juta q'ij.\n",
#  "Xiloma k'ut rechab'al kumal ri Junajpu,\n",
#  "                               Xb'alanke.\n",
#  "Kik'ak'alen chi k'ut chuxe' che' ri Wuqub' Kak'ix,\n",
#  "e matzamoj ulo ri ka'ib' k'ajolab' pa xaq che'\n",
#  "ta xopon k'ut Wuqub' Kak'ix\n",
#  "taqal chuwi recha' ri tapa'l.\n",
#  '\n',
#  "K'ate k'ut ta xub'axik kumal ri Junajpu:\n",
#  "taqal ub'aq' wub' chu kakate',\n",
#  "churaquj uchi' ta xpe chuwi che'\n",
#  'taqal chuwach ulew.\n',
#  "Chimalmat k'ut ri Junajpu,\n",
#  "anim xb'ek qitzij wi xb'e uchapa';\n",
#  "k'ate k'ut ta xqupix ula uq'ab' ri Junajpu rumal ri Wuqub' Kak'ix.\n",
#  "Jusuk' xtzaq uloq\n",
#  "       xmejo u1oq tzam uteleb';\n",
#  "ta xutzoqopij chi k'ut Junajpu ri Wuqub' Kak'ix.\n",
#  "Xawi utz xkib'ano,\n",
#  "ma nab'e kich'akatajik taj rumal Wuqub' Kak'ix.\n",
#  "Uk'a'am chi k'ut uq'ab' ri Junajpu rumal ri Wuqub' Kak'ix\n",
#  "ta xb'e chi rochoch.\n",
#  "Xa chi k'u ulotem ukakate' xoponik.\n",
#  "-Naki pa mixk'amow chi la? Xcha' k'u ri Chimalmat, rixoqil Wuqub' Kak'ix.\n",
#  "-Naki pa ri'?\n",
#  "Ri e ka'ib' k'axtok' mixikiwub'aj!\n",
#  "Mixsilib'ataj nukakate' rumal xa kachuywaj e we,\n",
#  "kaq'oxow chik! \n",
#  "Mi nab'e mixnuk'am uloq:\n",
#  "Chuwi q'aq' k'ut chixeke wi,\n",
#  "                 chitzayab' a chuwi q'aq',\n",
#  "ta kulkik'ama' chik qitzij chi e k'axtok'- Xcha' ri Wuqub' Kak'ix.\n",
#  "Ta xuxekeba' uq'ab' ri Junajpu.\n",
#  '\n',
#  "Kina'ojinik chik ri Junajpu,\n",
#  "                    'Xb'alanke.\n",
#  "Ta xkib'ij k'ut chi rech jun mama',\n",
#  "qitzij saq chik rismal wi chi mama';\n",
#  "jun k'u ati't,\n",
#  "qitzij kernel ati't chik;\n",
#  "xa keluq'ukila chik chi rijitaq winaq:\n",
#  "Saqi Nim Aq ub'i', mama'\n",
#  "Saqi Nima Tziz k'ut ub'i', ati't.\n",
#  "Xecha' k'u ri k'ajolab'Â· chi ke ri ati't,\n",
#  "                                   mama':\n",
#  "Kixqachb'ilaj taj,\n",
#  "chib'etak'ama' qaq'ab' ruk' Wuqub' Kak'ix.\n",
#  'Xa kojtere chi wij:\n',
#  "k'i ri qamam ri qachb'ilan,\n",
#  'kaminaq kichuch,\n',
#  '        kikajaw.\n',
#  "K'eje k'ut ketere,\n",
#  '      kekotila wi chi qij;\n',
#  'ta la keqasipaj wi.\n',
#  "Rumal xa elesan uchicopil eyaj kaqab'ano; kixcha'.\n",
#  "K'eje k'u ri oj ak'alab' chirilo ri Wuqub' Kak'ix.\n",
#  "Xawi oj kojyawik ina'oj-. Xecha' ri e ka'ib' k'ajolab'.\n",
#  "-Utz b'a la! Xecha' k'ut.\n",
#  '\n',
#  "K'ate k'ut ta xeb'ek,\n",
#  "tzamal k'u b'i ri Wuqub' Kak'ix,\n",
#  "chuwach uq'alib'al.\n",
#  "Ta xe'ik'owik ri ati't,\n",
#  "                 mama',\n",
#  "ke'etzeyaj k'u ri e ka'ib' k'ajolab' chi kij;\n",
#  "ta xe'ik'ow chuxe' rochoch ajaw,\n",
#  "kuraquj k'u uchi' ri Wuqub' Kak'ix rumal we.\n",
#  "Ta xril k'ut Wuqub' Kak'ix ri mama',\n",
#  "                              ati't kachb'ilan kib':\n",
#  "-Apa kixpe wi, qamam? Xcha' k'u ri ajaw.\n",
#  "-Xa oj tzuqub'ey qib', lal ajaw.- Xecha' k'ut.\n",
#  "-Naki pa itzuqub'al? ma iwalk'wal,\n",
#  "                   ri iwachb'ilan?\n",
#  "-Maja b'i, lal ajaw, e qamam ri,\n",
#  "xere na re kaqatoq'ob'aj kiwach\n",
#  "ri ya'axel ju pir,\n",
#  "      ch'aqap kaqaya' chi kech, lal ajaw.- Xecha' k'ut ri ati't,\n",
#  "                                                          mama'.\n",
#  "Kutzin k'u ri ajaw rumal uq'oxom we,\n",
#  "xa kunimaq wachij chik kach'awik:\n",
#  "-In ta b'a kanaj chi wech,\n",
#  "chitoq'ob'aj ta nuwach!\n",
#  "Naki pa ki chib'ano?\n",
#  "Naki on ki chikunaj? Xcha' k'ut ajaw.\n",
#  '-Xa uchikopil eyaj chiqelesaj,\n',
#  "xa k'u ub'aq uwach chiqakunaj,\n",
#  "xa b'aq chiqawiqo, lal ajaw.- Xecha' k'ut.\n",
#  "-Utz b'a la! Chikunaj ta b'a we,\n",
#  "qitzij kaq'oxowik juta q'ij,\n",
#  "mawi choq'itajik,\n",
#  "maja b'i nuwaram rumal ruk' ub'aq nuwach.\n",
#  "Xa xinki'ub'aj e ka'ib' k'axtok'.\n",
#  'Ta xtikarik mawi kinechajik rumal.\n',
#  "K'eje ta k'ut chitoq'ob'aj wi nuwach!\n",
#  "Xa kachuyub' we je chik ri we.\n",
#  "-Utz b'a la, lal ajaw:\n",
#  "chikop b'a kaq'uxuwik.\n",
#  "Xa chok ik'exel chel ri e la!\n",
#  "- Ma b'a utz lo chel ri we, rumal xere in ajaw wi:\n",
#  "nukawub'al ri we,\n",
#  "           ruk' ub'aq nuwach.\n",
#  "Xchikakoj chik na k'ut uk'exel,\n",
#  "jok'om b'aq xchok chik!\n",
#  "Are k'ut jok'om b'aq xri xa saqi ixim.\n",
#  "- Utz b'a la chiwelesaj, chito' uloq - . Xcha' k'ut.\n",
#  "Ta xel k'u ri re Wuqub' Kak'ix,\n",
#  "xa saqi ixim uk'exel re xokik.\n",
#  "Xa chi k'u saq julujuj chi ula ixim pu chi'.\n",
#  "Jusu k'u xqaj uwach,\n",
#  'mawi ajaw chik xwachinik.\n',
#  "Xk'is elik ri re k'uwal rax kawakoj pu chi'.\n",
#  "Ta xkunax chi k'ut ub'aq uwach Wuqub' Kak'ix,\n",
#  "ta xcholik ub'aq uwach,\n",
#  "xk'is elik ri puwaq, mana k'ax taj xuna'o,\n",
#  'xawi xere kamukunik.\n',
#  '\n',
#  "Ta xk'is k'u elik ri unimarisab'al rib',\n",
#  "xawi kina'oj ri Junajpu,\n",
#  "                Xb'alanke.\n",
#  "Ta xkam k'ut ri Wuqub' Kak'ix.\n",
#  "ta xuk'am k'ut uq'ab' ri Junajpu.\n",
#  'Xkam nay puch Chimalmat,\n',
#  "              rixoqil Wuqub' Kak'ix.\n",
#  '\n',
#  "K'eje k'ut usachik uq'inomal Wuqub' Kak'ix ri',\n",
#  "xa ajkun xk'amowik ri k'uwal,\n",
#  '           yamanik,\n',
#  "xupunab'ej waral chuwach ulew.\n",
#  "Nawal ati't,\n",
#  "nawal mama' xb'anowik.\n",
#  '\n',
#  "Ta xkik'am k'ut kiq'ab',\n",
#  'xtikitax ukoq.\n',
#  'Utz chik xuxik.\n',
#  "Xa rumal ukamik Wuqub' Kak'ix xkaj,\n",
#  "keje xkib'ano;\n",
#  "itzel xkilo nimarisab'al ib' .\n",
#  "K'ate k'ut xeb'e chik e ka'ib' k'ajolab',\n",
#  "xa utzij ri Uk'ux Kaj ta xkib'ano.\n",
#  "Wa'e chi k'ute ub'anoj chik sipakna,\n",
#  '\n',
#  "WA'E CHI K'UTE UB'ANOJ CHIK SIPAKNA,\n",
#  '\n',
#  "unab'e k'ajol Wuqub' Kak'ix.\n",
#  "- In b'anol juyub'! Kacha' ri Sipakna.\n",
#  "Are k'u ri Sipakna katinik chuchi' ja',\n",
#  "ta xe'ik'owik omuch' k'ajolab',\n",
#  "e jur wi che',\n",
#  "raqan kikab'al;\n",
#  "omuch' chub'inik,\n",
#  "ta xkiq'at k'ut jun nima che' uwapalil kikab'al.\n",
#  "K'ate k'ut xb'e ri Sipakna,\n",
#  "xopon k'u chila' kuk' ri omuch' k'ajolab':\n",
#  "- Naki pa kib'ano ix k'ajolab'?\n",
#  "- Xa che' mawi kaqayako\n",
#  "-Chiteleb'a'!\n",
#  'Xchintelej!\n',
#  'Apa kopon wi?\n',
#  "Naki pa uchak chi ik'ux?\n",
#  "-Xa uwapalil qakab'al.-\n",
#  "Utz b'a la!- Cha' k'ut.\n",
#  "Ta xujuruj k'ut,\n",
#  "xuteleb'a k'u aq'anoq chu chi kikab'al omuch' k'ajolab'.\n",
#  "-Xa ta wi katk'oje quk', at k'ajol!\n",
#  "k'o pa achuch,\n",
#  '       aqajaw?\n',
#  "-Maja b'i.- Xcha' k'ut.\n",
#  "-Kaqach'akimaj ta na b'a la chuweq chuwab'axik chik jun qache',\n",
#  "                                               raqan qakab'al.-\n",
#  "-Utz! Xcha' chi k'ut.\n",
#  "K'ate k'ut xk'am kina'oj ri omuch' k'ajolab':\n",
#  "-Are ri ala, japa cha' chiqab'an chi re?\n",
#  'Chiqakamisaj taj?\n',
#  "Rumal mawi utz ri kub'ano,\n",
#  "xa utukel mixuyak ri che'.\n",
#  "Qak'oto jun nima jul,\n",
#  "chiri' ta k'ut chiqatzaq wi qajoq pa jul.\n",
#  "Jak'ama' qaja ulew pa jul. Kojcha' ta chi re.\n",
#  "Chi are ta k'ut pachal qajoq pa jul,\n",
#  "ta qatarij qajoq ri nima che'.\n",
#  "Chiri' ta k'ut chikam wi pa jul.- Xecha' k'ut omuch' k'ajolab'.\n",
#  '\n',
#  "Ta xkik'ot k'ut jun nima jul,\n",
#  'najt xqajik.\n',
#  "Ta xkitaq k'ut ri Sipakna:\n",
#  '-Oj kanij chawech,\n',
#  "chib'eta ak'oto chik ulew,\n",
#  "mawi kaqariqo.- Xucha'xik.\n",
#  "-Utz b'a la! Xcha' k'ut.\n",
#  "K'ate k'ut xqaj pa jul.\n",
#  "-Kasik'in uloq ta k'ototajoq ri ulew,\n",
#  "naj ta chiqajik awumal.- Xucha'xik.\n",
#  "-We! Xcha' k'ut.\n",
#  "Ta xutik'ib'a uk'otik jul.\n",
#  "Xa k'u ujul xuk'oto,\n",
#  "       uk'olb'al rib';\n",
#  'xretamaj ri ukarnisaxik.\n',
#  "Ta xuk'ot k'ut jun wi chi jul\n",
#  "chu tzalanem ukab' jul xuk'oto xkolotaj wi.\n",
#  "- Kajanik'an pa la? Xuchax k'u qajoq kumal omuch' k'ajolab'.\n",
#  "- Kinanuk'oto,\n",
#  "we xkixnusik'ij aqanoq,\n",
#  "ta chutzinoq uk'ototajik.- Xcha' uloq Sipakna chiri' pa jul.\n",
#  "Ma k'u are kuk'ot uxe jul ri umuqikil,\n",
#  ...]

# %% [markdown]
# ## Encoding lines

# %%
for i in range(len(text)):
    offset = re.match(r'(\s+)', text[i]) ## matching the alignment space at the beginning of a line
    if offset is not None and len(text[i]) != 1: ## if there is at least one alignment space
        quantity = offset.end(0) ## stores the number of spaces
        text[i] = text[i].strip() ## removes the space in the string  
        text[i] = '<space quantity="' + str(quantity) + '" unit="chars" /><l>' + text[i] + "</l>" ## encodes each line
    elif text[i] == '\n':
        text[i] = '<lb /> <!-- potential div marker -->'
    else: ## if there are no alignment spaces
        text[i] = text[i].strip()
        text[i] = '<l>' + text[i] + '</l>'

# %%
text
# Out:
# ["<l>NAB'E</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>ARE' UXE' OJER TZIJ WARAL K'ICHE' UB'I'</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Waral xchiqatz'ib'aj wi,</l>",
#  '<space quantity="6" unit="chars" /><l>xchiqatikib\'a\' wi ojer tzij</l>',
#  "<l>utikarib'al,</l>",
#  "<l>uxe'nab'al puch ronojel xb'an pa tinamit K'iche'</l>",
#  '<space quantity="33" unit="chars" /><l>ramaq\' K\'iche\' winaq.</l>',
#  "<l>Are k'ut xchiqak'am wi:</l>",
#  "<l>uk'utunisaxik,</l>",
#  "<l>uq'alajob'isaxik,</l>",
#  '<l>utzijoxik puch</l>',
#  "<l>ewaxib'al,</l>",
#  "<l>saqirib'al rumal Tz'aqol,</l>",
#  '<space quantity="17" unit="chars" /><l>B\'itol,</l>',
#  '<space quantity="17" unit="chars" /><l>Alom,</l>',
#  '<space quantity="17" unit="chars" /><l>K\'ajolom kib\'i\'.</l>',
#  '<space quantity="17" unit="chars" /><l>Junajpu Wuch\',</l>',
#  '<space quantity="17" unit="chars" /><l>Junajpu Utiw,</l>',
#  '<space quantity="17" unit="chars" /><l>Saqinim Aq</l>',
#  '<space quantity="25" unit="chars" /><l>Sis</l>',
#  '<space quantity="17" unit="chars" /><l>Tepew,</l>',
#  '<space quantity="17" unit="chars" /><l>Q\'ukumatz,</l>',
#  '<space quantity="17" unit="chars" /><l>Uk\'ux Cho,</l>',
#  '<space quantity="17" unit="chars" /><l>Uk\'ux Palo,</l>',
#  '<space quantity="17" unit="chars" /><l>Ajraxa Laq,</l>',
#  '<space quantity="17" unit="chars" /><l>Ajraxa Tzel. Chucha\'xik,</l>',
#  '<space quantity="30" unit="chars" /><l>rachb\'ixik,</l>',
#  '<space quantity="30" unit="chars" /><l>rachtzijoxik ri Iyom,</l>',
#  '<space quantity="46" unit="chars" /><l>Mamom,</l>',
#  '<space quantity="46" unit="chars" /><l>Xpiyakok,</l>',
#  '<space quantity="46" unit="chars" /><l>Xmukane, ub\'i\'.</l>',
#  '<space quantity="46" unit="chars" /><l>Matzanel,</l>',
#  '<space quantity="46" unit="chars" /><l>Chuqenel,</l>',
#  '<space quantity="46" unit="chars" /><l>Kamul Iyom,</l>',
#  '<space quantity="46" unit="chars" /><l>Kamul Mamom.</l>',
#  '<space quantity="46" unit="chars" /><l>Chucha\'xik pa K\'iche\' tzij.</l>',
#  '<space quantity="49" unit="chars" /><l></l>',
#  '<l>Ta xkitzijoj ronojel</l>',
#  "<l>ruk' xkib'an chik</l>",
#  "<l>chi saqil k'olem,</l>",
#  '<space quantity="4" unit="chars" /><l>saqil tzij.</l>',
#  "<l>Wa'e xchiqatz'ib'aj chi upam chik</l>",
#  '<space quantity="24" unit="chars" /><l>uch\'ab\'al Dias,</l>',
#  '<space quantity="24" unit="chars" /><l>pa christianoil chik.</l>',
#  "<l>xchiqelesaj rumal maja b'i chik ilb'al re Popa Wuj,</l>",
#  '<space quantity="32" unit="chars" /><l>ilb\'al saq petenaq ch\'aqa palo</l>',
#  '<space quantity="39" unit="chars" /><l>utzijoxik qamujib\'al,</l>',
#  '<space quantity="32" unit="chars" /><l>ilb\'al saq k\'aslem\'; chucha\'xik.</l>',
#  "<l>K'o nab'e wujil,</l>",
#  "<l>ojer tzib'am puch,</l>",
#  '<l>xa ewal uwach ilol re,</l>',
#  '<space quantity="14" unit="chars" /><l>b\'isol re.</l>',
#  "<l>Nim upe'oxik,</l>",
#  '<l>utzijoxik puch,</l>',
#  "<l>ta chi k'is tz'uq ronojel kaj,</l>",
#  '<space quantity="26" unit="chars" /><l>ulew:</l>',
#  "<l>ukaj tz'uquxik,</l>",
#  '<l>ukaj xukutaxik,</l>',
#  '<space quantity="5" unit="chars" /><l>retaxik;</l>',
#  "<l>ukaj che'xik,</l>",
#  "<l>umej k'a'maxik,</l>",
#  "<l>uyuq k'a'maxik upa kaj,</l>",
#  '<space quantity="15" unit="chars" /><l>upa ulew;</l>',
#  "<l>kaj tz'uq,</l>",
#  "<l>kaj xukut, chucha'xik rumal ri Tz'aqol,</l>",
#  '<space quantity="31" unit="chars" /><l>B\'itol;</l>',
#  '<l>Uchuch,</l>',
#  "<l>Uqajaw k'aslem,</l>",
#  '<space quantity="7" unit="chars" /><l>Winaqirem:</l>',
#  "<l>Ab'anel,</l>",
#  "<l>K'uxlanel;</l>",
#  '<l>Alay rech,</l>',
#  "<l>K'uxlay rech saqil</l>",
#  '<space quantity="13" unit="chars" /><l>amaqil;</l>',
#  '<space quantity="13" unit="chars" /><l>saqil al,</l>',
#  '<space quantity="13" unit="chars" /><l>saqil k\'ajol;</l>',
#  "<l>Ajb'is,</l>",
#  "<l>Ajna'oj chi rech ronojel a ta k'ol wi kaj-ulew,</l>",
#  '<space quantity="38" unit="chars" /><l>cho-palo.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>ARE UTZIJOXIK WA'E</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>k'akatz'ininoq,</l>",
#  "<l>k'akachamamoq,</l>",
#  '<space quantity="3" unit="chars" /><l>katz\'inonik,</l>',
#  "<l>k'akasilanik,</l>",
#  "<l>k'akalolinik,</l>",
#  '<space quantity="3" unit="chars" /><l>katolona puch upa kaj.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Wa'e k'ute nab'e tzij,</l>",
#  '<space quantity="11" unit="chars" /><l>nab\'e uchan:</l>',
#  "<l>maja' b'i oq</l>",
#  '<space quantity="6" unit="chars" /><l>jun winaq,</l>',
#  '<space quantity="6" unit="chars" /><l>jun chikop,</l>',
#  '<space quantity="6" unit="chars" /><l>tz\'ikin,</l>',
#  '<space quantity="6" unit="chars" /><l>kar,</l>',
#  '<space quantity="6" unit="chars" /><l>tap,</l>',
#  '<space quantity="6" unit="chars" /><l>che\',</l>',
#  '<space quantity="6" unit="chars" /><l>ab\'aj,</l>',
#  '<space quantity="6" unit="chars" /><l>jul,</l>',
#  '<space quantity="6" unit="chars" /><l>siwan,</l>',
#  '<space quantity="6" unit="chars" /><l>k\'im,</l>',
#  '<space quantity="6" unit="chars" /><l>k\'ichelaj,</l>',
#  "<l>xa utukel kaj k'olik.</l>",
#  "<l>Mawi q'alaj uwach ulew,</l>",
#  '<l>xa utukel remanik palo</l>',
#  '<space quantity="12" unit="chars" /><l>upa kaj, ronojel.</l>',
#  "<l>Maja' b'i naki la' kamolob'ik,</l>",
#  '<space quantity="19" unit="chars" /><l>k\'akotzob\'ik,</l>',
#  '<space quantity="19" unit="chars" /><l>jun ta kasilob\'ik,</l>',
#  "<l>kumal kab'an taj,</l>",
#  "<l>k'akotz kab'an taj pa kaj:</l>",
#  "<l>xa ma k'o wi naki la' k'olik yakalik,</l>",
#  "<l>xa remanik ja',</l>",
#  "<l>xa li'anik palo,</l>",
#  '<l>xa utukel remanik,</l>',
#  "<l>xa ma k'o wi naki la' lo k'olik;</l>",
#  '<l>xa kachamanik,</l>',
#  '<space quantity="3" unit="chars" /><l>katz\'ininik chi q\'equ\'m,</l>',
#  '<space quantity="15" unit="chars" /><l>chi aq\'ab\'.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Xa utukel ri Tz'aqol,</l>",
#  '<space quantity="13" unit="chars" /><l>B\'itol,</l>',
#  '<space quantity="13" unit="chars" /><l>Tepew,</l>',
#  '<space quantity="13" unit="chars" /><l>Q\'ukumatz,</l>',
#  '<space quantity="13" unit="chars" /><l>e Alom,</l>',
#  '<space quantity="13" unit="chars" /><l>e K\'ajolom k\'o pa ja\'</l>',
#  '<space quantity="13" unit="chars" /><l>saqtetoj e k\'o wi.</l>',
#  "<l>E muqutal pa q'uq',</l>",
#  '<space quantity="10" unit="chars" /><l>pa raxon;</l>',
#  "<l>are ub'inam wi ri Q'ukumatz.</l>",
#  '<l>E nimaq etamanel,</l>',
#  "<l>e nimaq ajna'oj chi kik'oje'ik.</l>",
#  "<l>K'eje k'ut xax k'o wi ri kaj</l>",
#  "<l>k'o wi nay puch Uk'ux Kaj,</l>",
#  "<l>are' ub'i' ri kab'awil. Chuchaxik.</l>",
#  "<l>Ta xpe k'ut utzij waral,</l>",
#  "<l>xul kuk' ri Tepew,</l>",
#  '<space quantity="12" unit="chars" /><l>Q\'ukumatz waral chi q\'equmal</l>',
#  '<space quantity="28" unit="chars" /><l>chi aq\'ab\'al;</l>',
#  "<l>xch'aw ruk' ri Tepew,</l>",
#  '<space quantity="15" unit="chars" /><l>Q\'ukumatz.</l>',
#  "<l>Xecha' k'ut:</l>",
#  "<l>ta xena'ojinik,</l>",
#  "<l>ta xeb'isonik,</l>",
#  '<space quantity="3" unit="chars" /><l>xeriqo kib\',</l>',
#  '<space quantity="3" unit="chars" /><l>xkikuch kitzij,</l>',
#  '<space quantity="11" unit="chars" /><l>kina\'oj;</l>',
#  "<l>ta xq'alaj,</l>",
#  "<l>ta xkik'uxlaj kib' xe' wi saq,</l>",
#  "<l>ta xq'alaj puch winaq;</l>",
#  "<l>ta xkina'ojij utz'uqik,</l>",
#  '<space quantity="14" unit="chars" /><l>uwinaqirik che\',</l>',
#  '<space quantity="25" unit="chars" /><l>k\'a\'m,</l>',
#  '<space quantity="14" unit="chars" /><l>utz\'uquxik puch k\'aslem</l>',
#  '<space quantity="30" unit="chars" /><l>winaqirem</l>',
#  "<l>chi q'equmal,</l>",
#  "<l>chi aq'ab'al; rumal ri Uk'ux Kaj, Jun Raqan ub'i;</l>",
#  '<space quantity="23" unit="chars" /><l>Kaqulja Jun Raqan, nab\'e;</l>',
#  '<space quantity="23" unit="chars" /><l>ukab\' k\'ut, Ch\'ipi Kaqulja;</l>',
#  '<space quantity="23" unit="chars" /><l>rox chik, Raxa Kaqulja;</l>',
#  '<space quantity="2" unit="chars" /><l>chi e k\'u oxib\' ri\', Uk\'ux Kaj.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Ta xe'ul kuk' ri Tepew,</l>",
#  '<space quantity="17" unit="chars" /><l>Q\'ukumatz,</l>',
#  "<l>ta xna'ojixik saq k'aslem:</l>",
#  '<l>-Jupa cha ta chawaxoq,</l>',
#  '<space quantity="10" unit="chars" /><l>ta saqiroq puch?</l>',
#  '<l>Apachinaq tzuqul,</l>',
#  '<space quantity="10" unit="chars" /><l>k\'ool?</l>',
#  '<l>Ta chuxoq!</l>',
#  '<l>Kixnojin taj:</l>',
#  "<l>Are ri ja' chel taj!,</l>",
#  '<space quantity="11" unit="chars" /><l>chi jama\' taj!</l>',
#  '<l>Chiwinaqir wa ulew,</l>',
#  '<space quantity="14" unit="chars" /><l>ulaqel ta k\'u rib\'</l>',
#  "<l>Ch'ata k'ut.</l>",
#  '<l>Ta chawaxoq,</l>',
#  '<l>ta saqiroq kaj,</l>',
#  '<space quantity="11" unit="chars" /><l>ulew!</l>',
#  "<l>Mata k'ut uq'ijilab'al,</l>",
#  '<space quantity="10" unit="chars" /><l>uq\'ala\'ib\'al ri qatz\'aq</l>',
#  '<space quantity="23" unit="chars" /><l>ri qab\'it.</l>',
#  "<l>Ta winaqiroq: winaq tz'aq,</l>",
#  '<space quantity="14" unit="chars" /><l>winaq b\'it! Xecha\' k\'ut.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>TA XWINAQIR K'U RI ULEW KUMAL</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Xa kitzij xk'oje wi uwinaqirik.</l>",
#  '<l>Chiwinaqir ulew:</l>',
#  '<l>-Ulew! Xecha.</l>',
#  "<l>Lib'aj chi' xwinaqirik:</l>",
#  "<l>k'eje ri xa ta sutz',</l>",
#  '<space quantity="9" unit="chars" /><l>xa mayul uwinaqirik,</l>',
#  '<space quantity="11" unit="chars" /><l>chi k\'u pupuje\'ik.</l>',
#  "<l>Ta xtape pa ja' ri juyub',</l>",
#  '<space quantity="5" unit="chars" /><l>jusuk\' nima\'q juyub\' xuxik.</l>',
#  '<l>Xa kinawal,</l>',
#  "<l>xa kipus xb'anataj wi,</l>",
#  "<l>una'ojixik juyub',</l>",
#  '<space quantity="11" unit="chars" /><l>taq\'aj,</l>',
#  "<l>jusuk' rach winaqirik uq'isisil,</l>",
#  '<space quantity="22" unit="chars" /><l>upachÃ¤jil uwach.</l>',
#  "<l>K'eje k'ut xkikot wi ri Q'ukumatz:</l>",
#  "<l>-Utz mixatulik at Uk'ux Kaj,</l>",
#  '<space quantity="15" unit="chars" /><l>at Junraqan,</l>',
#  '<space quantity="15" unit="chars" /><l>at puch Ch\'ipi Kaqulja,</l>',
#  '<space quantity="23" unit="chars" /><l>Raxa Kaqulja!</l>',
#  '<l>Xchutzinik qatzak,</l>',
#  '<space quantity="11" unit="chars" /><l>qab\'it. Xecha\' k\'ut.</l>',
#  "<l>Nab'e k'ut xwinaqir ulew,</l>",
#  '<space quantity="20" unit="chars" /><l>juyub\'-taq\'aj;</l>',
#  "<l>xch'ob'och'ox ub'e ja':</l>",
#  "<l>xb'inije'ik k'ole je raqan xo'l taq juyub'</l>",
#  "<l>xa ch'ob'ol chik xek'oje wi ja,</l>",
#  "<l>ta xk'utunije'ik nima'q juyub'.</l>",
#  "<l>K'eje k'ut uwinaqirik ulew ri,</l>",
#  "<l>ta xwinaqirik kumal ri Uk'ux Kaj,</l>",
#  '<space quantity="23" unit="chars" /><l>Uk\'ux Ulew. Ke\'ucha\'xik.</l>',
#  '<space quantity="9" unit="chars" /><l></l>',
#  "<l>Ri' k'ut e nab'e xkinojij,</l>",
#  "<l>xk'olo wi ri kaj,</l>",
#  "<l>xk'olo nay puch ulew chi upam ja'.</l>",
#  "<l>K'eje k'ut uno'jixik ri,</l>",
#  "<l>ta xkino'jij,</l>",
#  "<l>ta xkib'isoj rutzinik,</l>",
#  '<space quantity="13" unit="chars" /><l>ub\'anatajik, kumal.</l>',
#  "<l>Ta xkino'jij chik uchikopil juyub',</l>",
#  '<space quantity="18" unit="chars" /><l>chajal re ki\'chelaj</l>',
#  '<space quantity="18" unit="chars" /><l>ronojel uwinaqil juyub\':</l>',
#  '<l>ri kyej,</l>',
#  "<l>tz'ikin,</l>",
#  '<l>koj,</l>',
#  "<l>b'alam,</l>",
#  '<l>kumatz,</l>',
#  '<l>sochoj,</l>',
#  '<l>kanti,</l>',
#  "<l>chajal k'a'm.</l>",
#  "<l>Kacha' ri Alom,</l>",
#  '<space quantity="10" unit="chars" /><l>K\'ajolom:</l>',
#  '<l>-Xa pa chi lolinik,</l>',
#  "<l>ma xa on chi tz'ininik uxe' che',</l>",
#  '<space quantity="28" unit="chars" /><l>k\'a\'m?</l>',
#  "<l>K'ate utz chi k'oje chajal re. Xecha' k'ut.</l>",
#  '<l>Ta xkinojij,</l>',
#  '<space quantity="3" unit="chars" /><l>xkitzijoj puch;</l>',
#  "<l>jusuk' xwinaqir kej,</l>",
#  '<space quantity="16" unit="chars" /><l>tz\'ikin.</l>',
#  "<l>Ta xkisipaj k'ut rochoch kej,</l>",
#  '<space quantity="25" unit="chars" /><l>tz\'ikin:</l>',
#  "<l>-At kej pa b'e ja',</l>",
#  '<space quantity="8" unit="chars" /><l>pa siwan katwar wi;</l>',
#  '<space quantity="8" unit="chars" /><l>waral katk\'oje\' wi;</l>',
#  '<space quantity="8" unit="chars" /><l>pa k\'im,</l>',
#  '<space quantity="8" unit="chars" /><l>pa saqul;</l>',
#  '<space quantity="8" unit="chars" /><l>pa k\'echelaj kipoqo wi iwib\'!</l>',
#  "<l>Kajkaj ib'inib'al,</l>",
#  '<space quantity="7" unit="chars" /><l>ichakab\'al, chuxik! Xe\'ucha\'xik.</l>',
#  "<l>Ta xkich'ik k'ut kochoch ch'uti tz'ikin,</l>",
#  '<space quantity="25" unit="chars" /><l>nima tz\'ikin:</l>',
#  "<l>-Ix, ix tz'ikin chuwi che',</l>",
#  '<space quantity="16" unit="chars" /><l>chuwi k\'a\'m kixochochin wi,</l>',
#  '<space quantity="28" unit="chars" /><l>kixja\'in wi!</l>',
#  '<space quantity="16" unit="chars" /><l>chi ri\' kixpoq wi,</l>',
#  '<space quantity="24" unit="chars" /><l>kixk\'iritaj wi</l>',
#  '<space quantity="16" unit="chars" /><l>chuq\'ab\' che\',</l>',
#  '<space quantity="16" unit="chars" /><l>chuq\'ab\' k\'a\'m! Xe\'ucha\'xik kyej,</l>',
#  '<space quantity="44" unit="chars" /><l>tz\'ikin.</l>',
#  "<l>Ta xkib'ano</l>",
#  '<space quantity="3" unit="chars" /><l>kib\'anoj,</l>',
#  "<l>ronojel xuk'amo uwarab'al,</l>",
#  '<space quantity="16" unit="chars" /><l>uyakalib\'al.</l>',
#  "<l>K'eje k'ut kochoch wi chikop ri ulew xuya'o Alom,</l>",
#  '<space quantity="44" unit="chars" /><l>K\'ajolom;</l>',
#  '<l>xutzininaq chik ronojel ri kej,</l>',
#  '<space quantity="27" unit="chars" /><l>tz\'ikin.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Ta xe'uchax chi k'ut ri kej,</l>",
#  '<space quantity="24" unit="chars" /><l>tz\'ikin; rumal Tz\'aqol,</l>',
#  '<space quantity="39" unit="chars" /><l>B\'itol,</l>',
#  '<space quantity="39" unit="chars" /><l>Alom,</l>',
#  '<space quantity="39" unit="chars" /><l>K\'ajolom:</l>',
#  "<l>-Kixch'awoq,</l>",
#  "<l>Kixsik'inoq!</l>",
#  '<l>mixyonolikinik,</l>',
#  "<l>mixsik'inik!</l>",
#  "<l>Kixch'awajetaj chi jujunal,</l>",
#  '<space quantity="15" unit="chars" /><l>chu jutaq ch\'ob\'il,</l>',
#  '<space quantity="15" unit="chars" /><l>chi jutaq molajil!</l>',
#  "<l>Xe'ucha'xik ri kej,</l>",
#  '<space quantity="15" unit="chars" /><l>tz\'ikin,</l>',
#  '<space quantity="15" unit="chars" /><l>koj,</l>',
#  '<space quantity="15" unit="chars" /><l>b\'alam,</l>',
#  '<space quantity="15" unit="chars" /><l>kumatz.</l>',
#  "<l>-Chib'ij na k'ut ri qab'i',</l>",
#  '<l>Kojiqajarisaj, oj ichuch,</l>',
#  '<space quantity="15" unit="chars" /><l>oj iqajaw!</l>',
#  "<l>Kixcha' b'a na k'ut:</l>",
#  '<space quantity="3" unit="chars" /><l>Junraqan,</l>',
#  '<space quantity="3" unit="chars" /><l>Ch\'ipi Kaqulja,</l>',
#  '<space quantity="3" unit="chars" /><l>Raxa Kaqulja;</l>',
#  '<space quantity="3" unit="chars" /><l>Uk\'ux Kaj,</l>',
#  '<space quantity="3" unit="chars" /><l>Uk\'ux Ulew;</l>',
#  '<space quantity="3" unit="chars" /><l>Tz\'aqol,</l>',
#  '<space quantity="3" unit="chars" /><l>B\'itol;</l>',
#  '<space quantity="3" unit="chars" /><l>Alom,</l>',
#  '<space quantity="3" unit="chars" /><l>K\'ajolom.</l>',
#  '<space quantity="3" unit="chars" /><l>Kixch\'awoq,</l>',
#  '<space quantity="3" unit="chars" /><l>Kojiq\'ijila\'! Xe\'ucha\'xik.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Ma k'u xutzinik</l>",
#  '<space quantity="7" unit="chars" /><l>xech\'awik k\'eje ta ri winaq.</l>',
#  '<l>Xa kewachelajik,</l>',
#  "<l>xa kek'aralajik,</l>",
#  '<l>xa kewojonik;</l>',
#  "<l>mawi xwachinik uwach kich'ab'al.</l>",
#  "<l>Jalajoj xkoq'ib'ej chi kijujunal.</l>",
#  "<l>Ta xkita ri Tz'aqol,</l>",
#  '<space quantity="12" unit="chars" /><l>B\'itol,</l>',
#  '<l>mawi mixutzinik,</l>',
#  '<space quantity="5" unit="chars" /><l>mixech\'awik.</l>',
#  "<l>Xecha' chik chi kib'il kib':</l>",
#  "<l>-Mawi mixutzin ub'ixik qab'i';</l>",
#  "<l>rumal oj kajtz'aq,</l>",
#  '<space quantity="6" unit="chars" /><l>oj pu kajb\'it: mawi utz!-</l>',
#  "<l>Xecha' chik chi kib'il kib' ri Alom,</l>",
#  '<space quantity="31" unit="chars" /><l>K\'ajolom.</l>',
#  "<l>Xe'uchax k'ut:</l>",
#  '<l>Xa kixjalatajik rumal mawi mixutzinik,</l>',
#  '<space quantity="22" unit="chars" /><l>mawi mixixch\'awik.</l>',
#  "<l>Mi k'u xqajal qatzij;</l>",
#  '<space quantity="14" unit="chars" /><l>iwecha\',</l>',
#  '<space quantity="14" unit="chars" /><l>ik\'uxun;</l>',
#  '<space quantity="14" unit="chars" /><l>iwarab\'al,</l>',
#  '<space quantity="14" unit="chars" /><l>iyakalib\'al;</l>',
#  "<l>Ri wech wi mixe'uxik siwan,</l>",
#  '<space quantity="11" unit="chars" /><l>k\'echelaj rumal mawi xutzin qaq\'ijiloxik,</l>',
#  '<space quantity="27" unit="chars" /><l>mawi ixsik\'iy qe.</l>',
#  "<l>K'a k'o,</l>",
#  "<l>k'o wi lo q'ijilonel,</l>",
#  '<space quantity="10" unit="chars" /><l>nimanel chi qab\'an chik!</l>',
#  "<l>Xa chik'am ipatan:</l>",
#  "<l>xa ityo'jil chikach'ik.</l>",
#  "<l>Ta chuxoq! Are k'ut chipatanij. Xe'ucha'xik.</l>",
#  "<l>Ta xepixab'axik ch'uti chikop,</l>",
#  '<space quantity="16" unit="chars" /><l>nima chikop k\'o chuwach ulew.</l>',
#  "<l>Ta xraj k'u kitij chik kiq'ij;</l>",
#  '<space quantity="3" unit="chars" /><l>xraj kitijtob\'ej chik,</l>',
#  '<space quantity="3" unit="chars" /><l>xraj pu kinuk\' chik q\'ijilab\'al.</l>',
#  "<l>Xa ma xkita wi kich'ab'al chi kib'il kib'.</l>",
#  "<l>Xa ma xnawachir wi k'ut,</l>",
#  "<l>xa ma b'anataj wi puch.</l>",
#  "<l>K'eje k'ut xech'akataj wi kityo'jil.</l>",
#  '<l>Xkipatanij: xetiyik,</l>',
#  '<space quantity="12" unit="chars" /><l>xekamisaxik ri chikop k\'o waral chuwach ulew.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'EJE K'UT UTIJTOB'EXIK CHIK WINAQ TZ'AQ,</l>",
#  '<space quantity="29" unit="chars" /><l>WINAQ B\'IT KUMAL Tz\'aqol</l>',
#  '<space quantity="46" unit="chars" /><l>B\'itol;</l>',
#  '<space quantity="46" unit="chars" /><l>Alom,</l>',
#  '<space quantity="46" unit="chars" /><l>K\'ajolom;</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>-Xa k'u tija chik</l>",
#  '<l>mixyopij rawexik ,</l>',
#  '<space quantity="9" unit="chars" /><l>usaqirik?</l>',
#  "<l>Qab'ana' tzuqul qe,</l>",
#  '<space quantity="9" unit="chars" /><l>k\'ool qe.</l>',
#  "<l>Ju pa cha ta kojsik'ixoq,</l>",
#  '<space quantity="10" unit="chars" /><l>ta kojnab\'ax puch chuwach ulew?</l>',
#  "<l>Mixqatijo chi rech ri nab'e qatz'aq,</l>",
#  '<space quantity="28" unit="chars" /><l>qab\'it.</l>',
#  "<l>Mawi mixutzinik qaq'ijiloxik,</l>",
#  '<space quantity="16" unit="chars" /><l>qaq\'alajixik puch kumal.</l>',
#  "<l>K'eje k'ut qatija wi ub'anik ajnim,</l>",
#  '<space quantity="29" unit="chars" /><l>ajxob\';</l>',
#  '<space quantity="29" unit="chars" /><l>tzuqul,</l>',
#  '<space quantity="29" unit="chars" /><l>k\'ool! Xecha\'.</l>',
#  "<l>Ta utz'aqik k'ut,</l>",
#  '<space quantity="3" unit="chars" /><l>ub\'anik puch ulew,</l>',
#  '<space quantity="16" unit="chars" /><l>xoq\'o\'l utyo\'jil xkib\'ano.</l>',
#  '<l>Ma ku utz xkilo:</l>',
#  '<l>xa chi yojomanik,</l>',
#  "<l>xa tzub'ulik,</l>",
#  "<l>xa neb'elik,</l>",
#  "<l>xa lub'anik,</l>",
#  '<l>xa wulanik,</l>',
#  "<l>xa pu chi'umarik.</l>",
#  "<l>Mawi chi k'olol ujolom,</l>",
#  "<l>xa jun b'enaq wi uwach,</l>",
#  "<l>xa ku'l uwach;</l>",
#  '<l>mawi chi mukun chi rij.</l>',
#  "<l>Chi ch'aw nab'e maja b'i una'oj.</l>",
#  "<l>xa jusuk' chi'umar pa ja'.</l>",
#  "<l>-Mawi k'o-; xecha' chi k'u ri Ajtz'aq,</l>",
#  '<space quantity="30" unit="chars" /><l>Ajb\'it.</l>',
#  "<l>Qaw achlab'eq!</l>",
#  '<l>Ta chuxoq!</l>',
#  "<l>Xa lab'e mawi chib'inik,</l>",
#  '<space quantity="9" unit="chars" /><l>ma pu chipoq\'otajik.</l>',
#  '<l>Ta chuxoq!</l>',
#  "<l>Xa una'oj chiri'! Xecha'.</l>",
#  "<l>Ta xkiyoj k'ut,</l>",
#  '<space quantity="3" unit="chars" /><l>xkiyoq\' chik ri kitz\'aq,</l>',
#  '<space quantity="19" unit="chars" /><l>kib\'it.</l>',
#  "<l>Xecha' chi k'ut:</l>",
#  "<l>-Jupa cha ki chiqab'ano?</l>",
#  '<l>Chutzin ta wi,</l>',
#  '<l>chinawachir ta wi</l>',
#  "<l>q'ijiloy qech,</l>",
#  '<space quantity="2" unit="chars" /><l>siq\'iy qech? Xecha\' ta xkina\'ojij chik:</l>',
#  "<l>-Xa qab'ij chi ke Xpiyakok,</l>",
#  '<space quantity="18" unit="chars" /><l>Xmukane;</l>',
#  '<space quantity="18" unit="chars" /><l>Junajpu Wuch\',</l>',
#  '<space quantity="18" unit="chars" /><l>Junajpu Utiw;</l>',
#  "<l>kitija chik uq'ijixik,</l>",
#  '<space quantity="12" unit="chars" /><l>ub\'itaxik-.</l>',
#  "<l>Xe'uchan ki kib' Ajtz'aq,</l>",
#  '<space quantity="17" unit="chars" /><l>Ajb\'it.</l>',
#  "<l>Ta xkib'ij k'ut chi re Xpiyakok,</l>",
#  '<space quantity="23" unit="chars" /><l>Xmukane.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'ATE K'UT UB'IXIK RI' CHI KECH RI E NIK'WACHINEL,</l>",
#  "<l>Rati't Q'ij,</l>",
#  "<l>Rati't Saq, ke'ucha'xik kumal ri Tz'aqol,</l>",
#  '<space quantity="33" unit="chars" /><l>B\'itol.</l>',
#  "<l>Are kib'i' ri Xpiyakok,</l>",
#  '<space quantity="14" unit="chars" /><l>Xmukane.</l>',
#  "<l>Xecha' k'u ri Juraqan ruk' Tepew,</l>",
#  '<space quantity="27" unit="chars" /><l>Q\'ukumatz;</l>',
#  "<l>ta xkib'ij chi rech ajq'ij,</l>",
#  '<space quantity="20" unit="chars" /><l>ajb\'it,</l>',
#  '<space quantity="20" unit="chars" /><l>e nik\'wachinel:</l>',
#  "<l>-Xa k'ulu</l>",
#  "<l>xa pu churiqo che ta chik chiqawinaq-b'itoj,</l>",
#  '<space quantity="26" unit="chars" /><l>chiqawinaq-tz\'aqoj ta chik tzuqul,</l>',
#  '<space quantity="53" unit="chars" /><l>k\'ool,</l>',
#  "<l>kojsik'ix taj,</l>",
#  "<l>kojnab'ax taj puch.</l>",
#  "<l>Katok ta k'ut pa tzij Iyom,</l>",
#  '<space quantity="22" unit="chars" /><l>Mamom;</l>',
#  '<space quantity="22" unit="chars" /><l>qati\'t</l>',
#  '<space quantity="22" unit="chars" /><l>qamam;</l>',
#  '<space quantity="22" unit="chars" /><l>Xpiyakok,</l>',
#  '<space quantity="22" unit="chars" /><l>Xmukane:</l>',
#  '<l>cha taj ta chawaxoq,</l>',
#  '<space quantity="8" unit="chars" /><l>ta saqiroq:</l>',
#  "<l>qasik'ixik,</l>",
#  "<l>qatoq'exik,</l>",
#  "<l>qanab'axik rumal winaq tz'aq,</l>",
#  '<space quantity="17" unit="chars" /><l>winaq b\'it,</l>',
#  '<space quantity="17" unit="chars" /><l>winaq poy,</l>',
#  '<space quantity="17" unit="chars" /><l>winaq anom;</l>',
#  '<l>cha ta chuxoq!</l>',
#  "<l>Chik'utun ib'i' Junajpu Wuch',</l>",
#  '<space quantity="16" unit="chars" /><l>Junajpu Utiw;</l>',
#  '<space quantity="16" unit="chars" /><l>Kamul Alom,</l>',
#  '<space quantity="16" unit="chars" /><l>Kamul K\'ajolom;</l>',
#  '<space quantity="16" unit="chars" /><l>Nim Aq,</l>',
#  '<space quantity="16" unit="chars" /><l>Nima Sis,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajk\'uwal,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajyamanik,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajch\'ut,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajtz\'alam,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajraxa laq,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajraxa tzel,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajq\'ol,</l>',
#  '<space quantity="16" unit="chars" /><l>Ajtoltekat,</l>',
#  '<space quantity="16" unit="chars" /><l>Rati\'t Q\'ij,</l>',
#  '<space quantity="16" unit="chars" /><l>Rati\'t Saq; kixucha\'xik rumal qatz\'aq,</l>',
#  '<space quantity="46" unit="chars" /><l>qab \'it!</l>',
#  '<l>Chimala chi ixim,</l>',
#  '<space quantity="8" unit="chars" /><l>chi tz\'ite\':</l>',
#  "<l>xa chib'anatajik,</l>",
#  '<l>xa pu chel apanoq,</l>',
#  "<l>chiq'ajaj,</l>",
#  "<l>chik'ak'otaj puch uchi',</l>",
#  '<space quantity="18" unit="chars" /><l>uwach che\'-. Xe\'ucha\'xik e ajq\'ij.</l>',
#  "<l>K'ate puch uqajik,</l>",
#  '<space quantity="11" unit="chars" /><l>uq\'ijiloxik ri xmalik chi ixim,</l>',
#  '<space quantity="33" unit="chars" /><l>chi tz\'ite\':</l>',
#  "<l>-Q'ij,</l>",
#  "<l>b'it! Xecha' k'u ri jun ati't,</l>",
#  '<space quantity="20" unit="chars" /><l>jun mama\' chi kech.</l>',
#  "<l>Are ri mama' are ajtz'ite', Xpiyakok ub'i';</l>",
#  "<l>are k'u ri ati't ajq'ij,</l>",
#  '<space quantity="17" unit="chars" /><l>ajb\'it chi raqan, Xmukane ub\'i\'.</l>',
#  "<l>Xecha' k'ut ta xkitikib'a' q'ij:</l>",
#  "<l>-Xa chuk'ulu,</l>",
#  '<l>xa pu churiqo;</l>',
#  "<l>chab'ij,</l>",
#  '<l>kuta qaxikin;</l>',
#  "<l>kach'awik,</l>",
#  '<l>katzijon taj.</l>',
#  "<l>Xa chuk'ulu ri che' chajawaxik,</l>",
#  '<space quantity="20" unit="chars" /><l>chik\'otox puch kumal Ajtz\'aq,</l>',
#  '<space quantity="41" unit="chars" /><l>Ajb\'it.</l>',
#  '<l>We are tzuqul,</l>',
#  '<space quantity="7" unit="chars" /><l>k\'ool;</l>',
#  '<l>ta chawaxoq,</l>',
#  '<l>ta saqiroq!</l>',
#  '<l>at ixim,</l>',
#  "<l>at tz'ite';</l>",
#  "<l>at q'ij,</l>",
#  "<l>at b'it katchokonik,</l>",
#  '<space quantity="8" unit="chars" /><l>kattaqen taj-. Xcha\' chi re ixim,</l>',
#  '<space quantity="36" unit="chars" /><l>tz\'ite\',</l>',
#  '<space quantity="36" unit="chars" /><l>q\'ij,</l>',
#  '<space quantity="36" unit="chars" /><l>b\'it.</l>',
#  "<l>-Katk'ix la uloq at Uk'ux Kaj,</l>",
#  "<l>ma qajisaj uchi',</l>",
#  '<space quantity="11" unit="chars" /><l>uwach Tepew,</l>',
#  '<space quantity="17" unit="chars" /><l>Q\'ukumatz-. Xecha\' ta xkib\'ij k\'ut usuk\'ulikil</l>',
#  '<l>Utz are chuxik ri ipoy,</l>',
#  '<space quantity="18" unit="chars" /><l>ajam che\' chich\'awik,</l>',
#  '<space quantity="28" unit="chars" /><l>chitzijon b\'a la chuwach ulew.</l>',
#  "<l>Ta chuxoq! Xecha' k'ut.</l>",
#  "<l>Ta xkib'ij jusuk' xb'anik poy,</l>",
#  '<space quantity="26" unit="chars" /><l>ajam che\'.</l>',
#  '<l>Xewinaq-wachinik,</l>',
#  '<l>xewinaq-tzijonik puch;</l>',
#  "<l>are' winaqil uwach ulew xe'uxik,</l>",
#  "<l>xepoq'ik,</l>",
#  "<l>xeme'alanik,</l>",
#  "<l>xek'ajolanik ri poy,</l>",
#  '<space quantity="16" unit="chars" /><l>ajam che\'.</l>',
#  "<l>Ma k'u ja b'i kik'ux,</l>",
#  "<l>ma pu ja b'i kina'oj;</l>",
#  "<l>mawi na'tal kajtz'aq,</l>",
#  '<space quantity="12" unit="chars" /><l>kajb\'it.</l>',
#  "<l>Xa loq' xeb'inik,</l>",
#  '<space quantity="8" unit="chars" /><l>xechakanik.</l>',
#  "<l>Mawi xkina'taj chik ri Uk'ux Kaj.</l>",
#  "<l>K'eje k'ut xepaj chiri':</l>",
#  "<l>xa utijtob'exik,</l>",
#  "<l>xa pu uwab'ab'exik chi winaq.</l>",
#  "<l>Kechaw nab'e;</l>",
#  "<l>xa chaqi'j kiwach,</l>",
#  '<l>mana sonol kaqan,</l>',
#  '<space quantity="11" unit="chars" /><l>kiq\'ab\';</l>',
#  "<l>maja b'i kikik'el,</l>",
#  '<space quantity="9" unit="chars" /><l>kikomajil ,</l>',
#  "<l>maja b'i kitiqowal,</l>",
#  '<space quantity="9" unit="chars" /><l>kikab\'chijal.</l>',
#  "<l>Chaqi'j kotz,</l>",
#  "<l>k'oj kiwach.</l>",
#  '<l>Kapichipoj kaqan,</l>',
#  '<space quantity="11" unit="chars" /><l>kiq\'ab\';</l>',
#  "<l>Kayeyoj kityo'jil.</l>",
#  "<l>K'eje k'ut mawi xena'w chi ri' chuwach Tz'aqol,</l>",
#  '<space quantity="39" unit="chars" /><l>B\'itol,</l>',
#  '<space quantity="39" unit="chars" /><l>Alay Qech,</l>',
#  '<space quantity="39" unit="chars" /><l>K\'uxla\'y Qech.</l>',
#  "<l>E nab'e tzatz chi winaq xe'uxik waral chuwach ulew.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'ATE K'UT KIK'ISIK CHIK,</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>kima'ixik,</l>",
#  "<l>kik'utuxik puch;</l>",
#  '<l>xekamisax chik poy,</l>',
#  '<space quantity="15" unit="chars" /><l>ajam che\'.</l>',
#  "<l>Ta xna'ojix kib'utik rumal Uk'ux Kaj;</l>",
#  "<l>nima b'utik xb'anik:</l>",
#  '<l>xpe pa kiwi ri e poy,</l>',
#  '<space quantity="15" unit="chars" /><l>e ajam che\'.</l>',
#  "<l>Tz'ite' utyo'jil ri achij ta xajaxik rumal Tz'aqol,</l>",
#  '<space quantity="43" unit="chars" /><l>B\'itol;</l>',
#  "<l>ixoq, sib'ak k'ut utyo'jil ixoq xraj okik rumal Tz'aqol,</l>",
#  '<space quantity="48" unit="chars" /><l>B\'itol.</l>',
#  "<l>Mawi xena'wik,</l>",
#  "<l>ma pu xech'awik chuwach kajtz'aq,</l>",
#  '<space quantity="24" unit="chars" /><l>kajb\'it;</l>',
#  '<space quantity="24" unit="chars" /><l>b\'anol ke,</l>',
#  '<space quantity="24" unit="chars" /><l>winaqirisay kech.</l>',
#  "<l>K'eje k'ut kikamisaxik,</l>",
#  '<space quantity="11" unit="chars" /><l>xeb\'utik:</l>',
#  "<l>xpe nima q'ol chila' chi kaj,</l>",
#  "<l>xpe k'otk'owach ub'i' xk'otin uloq ub'aq' kiwach;</l>",
#  "<l>xepe kamalotz' xqupin ula kijolom.</l>",
#  "<l>xpe kotzb'alam xti'o kityo'jil.</l>",
#  "<l>xpe tukumb'alam xtukuwik,</l>",
#  '<space quantity="16" unit="chars" /><l>xkichowik kib\'aqil,</l>',
#  '<space quantity="26" unit="chars" /><l>kib\'ochil.</l>',
#  '<l>Xqajixik,</l>',
#  "<l>xmuchulixik kib'aqil;</l>",
#  "<l>k'ajisab'al kiwach rumal mawi kinawik chuwach kichuch,</l>",
#  '<space quantity="38" unit="chars" /><l>chuwach puch kikajaw;</l>',
#  '<space quantity="38" unit="chars" /><l>Ri Uk\'ux Kaj,</l>',
#  '<space quantity="38" unit="chars" /><l>Juraqan ub\'i\'.</l>',
#  "<l>Kumal xq'equ'marik uwach ulew:</l>",
#  "<l>xtikarik q'eqal jab',</l>",
#  "<l>q'ijil jab',</l>",
#  "<l>aqab'al jab'</l>",
#  "<l>xok ula' ch'uti chikop,</l>",
#  '<space quantity="9" unit="chars" /><l>nima chikop.</l>',
#  "<l>xkut kiwach rumal che',</l>",
#  '<space quantity="18" unit="chars" /><l>ab\'aj.</l>',
#  "<l>Xch'awik ronojel kiq'eb'al,</l>",
#  '<space quantity="17" unit="chars" /><l>kixot,</l>',
#  '<space quantity="17" unit="chars" /><l>kilaq,</l>',
#  '<space quantity="17" unit="chars" /><l>kib\'o\'j,</l>',
#  '<space quantity="17" unit="chars" /><l>kitz\'i\',</l>',
#  '<space quantity="17" unit="chars" /><l>kika\';</l>',
#  "<l>jaruj pa' la ronojel xkutu kiwach.</l>",
#  "<l>-k'ax xib'an chi qe:</l>",
#  '<l>xojitiyo,</l>',
#  "<l>ix chi k'ut</l>",
#  "<l>xkixqati' chik! Xcha' ri kitz'i'</l>",
#  '<space quantity="25" unit="chars" /><l>kak\' chi kech.</l>',
#  "<l>Are k'u ri ka':</l>",
#  "<l>- xojk'ok'onik iwumal juta q'ij,</l>",
#  '<space quantity="22" unit="chars" /><l>juta q\'ij;</l>',
#  '<space quantity="22" unit="chars" /><l>xq\'ek,</l>',
#  '<space quantity="22" unit="chars" /><l>saqirik;</l>',
#  "<l>amaq'el joli,</l>",
#  '<space quantity="8" unit="chars" /><l>joli;</l>',
#  '<space quantity="8" unit="chars" /><l>juk\'i,</l>',
#  '<space quantity="8" unit="chars" /><l>juk\'i qawach iwumal.</l>',
#  "<l>Are ta nab'e qapatan chi wach</l>",
#  "<l>ix ta na winaq wakamik k'ut</l>",
#  "<l>xchitij qachuqab':</l>",
#  "<l>xchiqake'j,</l>",
#  "<l>xchiqajok' puch ityo'jil! Xcha' ri kika' chi ke.</l>",
#  "<l>Are k'u ri kitz'i' xcha' chik ta xch'awik:</l>",
#  "<l>-Naki pa rumal mawi chiya' qawa?</l>",
#  '<l>xa kojmukunik,</l>',
#  '<l>xa pu kojikuxij uloq,</l>',
#  '<space quantity="6" unit="chars" /><l>kojitzaq pu uloq;</l>',
#  "<l>yakal ub'i qache'el iwumal ta kixwa'ik.</l>",
#  "<l>Xere kojiwucha'aj wi,</l>",
#  "<l>mawi kojch'awik.</l>",
#  "<l>Mata k'u mixojkamik iwumal!</l>",
#  '<l>-Jupa cha mawi mixixnawik</l>',
#  "<l>xixnaw ta k'ut;</l>",
#  "<l>chi wij ta k'ut xojsach wi.</l>",
#  "<l>Wakamik k'ut xchitij qab'aq k'o pa qachi':</l>",
#  "<l>xkixqati'o! Xecha' ri tz'i' chi ke ta xkut kiwach.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Are chi k'u ri kixot,</l>",
#  '<space quantity="15" unit="chars" /><l>kib\'o\'j xch\'aw chik chi ke:</l>',
#  "<l>- K'ax wa xib'an chi qe:</l>",
#  "<l>xaq qachi',</l>",
#  '<l>xaq qawach;</l>',
#  "<l>amaq'el ojtzaqal chuwi q'aq'</l>",
#  "<l>kojik'ato.</l>",
#  "<l>Mawi k'ax xqana'o?</l>",
#  "<l>xchitij k'ut: xkixqaporoj! Xcha' ri kib'o'j.</l>",
#  '<l>Ronojel xkutu kiwach.</l>',
#  "<l>Are ri ab'aj,</l>",
#  '<space quantity="4" unit="chars" /><l>ri kixk\'ub\' chitaninik chipe pa q\'aq\',</l>',
#  '<l>taqal chi kijolom.</l>',
#  "<l>K'ax xb'an chi ke.</l>",
#  "<l>Anilab'ik</l>",
#  "<l>kemalmalijab' chik;</l>",
#  "<l>keraj aq'anik chuwi ja,</l>",
#  '<space quantity="7" unit="chars" /><l>xa chi wulij ja ketzaq uloq;</l>',
#  "<l>keraj aq'an chuwi che',</l>",
#  '<space quantity="6" unit="chars" /><l>kech\'akix uloq rumal che\'.</l>',
#  '<l>Keraj ok pa jul,</l>',
#  '<space quantity="6" unit="chars" /><l>xa chiyuch jul chi kiwach.</l>',
#  "<l>K'eje k'ut ukayojik winaq tz'aq,</l>",
#  '<space quantity="20" unit="chars" /><l>winaq b\'it,</l>',
#  '<l>e tzixel,</l>',
#  '<l>e tzalatzoxel chi winaq.</l>',
#  "<l>Xma'ixik,</l>",
#  "<l>xk'utuxik kichi',</l>",
#  '<space quantity="10" unit="chars" /><l>kiwach konojel.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Xcha' k'ut are retal ri k'oy k'o pa k'echelaj wakamik.</l>",
#  "<l>Are xk'oje wi retal rumal xa che' kityo'jil xkojik rumal Ajtz'aq,</l>",
#  '<space quantity="57" unit="chars" /><l>Ajb\'it.</l>',
#  "<l>Are k'u ri k'oy keje ri winaq chiwachinik,</l>",
#  "<l>retal ju le' winaq tz'aq,</l>",
#  '<space quantity="13" unit="chars" /><l>winaq b\'it;</l>',
#  '<l>xa poy,</l>',
#  "<l>xa pu ajam che'.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>UKAB'</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>ARE K'UT XA JUB'IQ' SAQNATANOJ UWACH ULEW,</l>",
#  '<space quantity="20" unit="chars" /><l>MAJA B\'I Q\'IJ</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Jun k'ut kunimarisaj rib' Wuqub' Kaq'ix, ub'i'.</l>",
#  "<l>K'o nab'e kaj,</l>",
#  '<space quantity="10" unit="chars" /><l>ulew,</l>',
#  "<l>xa kamoymot uwach q'ij,</l>",
#  '<space quantity="18" unit="chars" /><l>ik\'.</l>',
#  "<l>Kacha' k'u ri':</l>",
#  "<l>Xawi xere usaqetal winaq ri xb'utik,</l>",
#  "<l>keje ri nawal winaq uk'oje'ik;</l>",
#  "<l>-In nim kik'oje chik chuwi winaq tzaq,</l>",
#  '<space quantity="27" unit="chars" /><l>winaq b\'it:</l>',
#  "<l>in qu'ij,</l>",
#  '<l>in pu usaq,</l>',
#  "<l>in nay pu rik'il; ta chuxoq!</l>",
#  '<l>Nim nusaqil,</l>',
#  "<l>in b'inib'al,</l>",
#  "<l>in pu chakab'al rumal winaq!</l>",
#  "<l>Rumal puwaq ub'aq nuwach xa katiltotik chi yamanik,</l>",
#  '<space quantity="43" unit="chars" /><l>raxa k\'uwal;</l>',
#  "<l>nay pu we rax kawakoj chi ab'aj keje ri uwa kaj.</l>",
#  "<l>Are k'u ri nutza'm saq julujuj chi naj k'eje ri ik'.</l>",
#  "<l>Puwaq k'ut nuq'alib'al:</l>",
#  "<l>k'a saq pak'e uwach ulew ta kinel uloq chuwach nuq'alib'al.</l>",
#  "<l>K'eje k'ut in q'ij wi,</l>",
#  '<space quantity="11" unit="chars" /><l>in pu ik\' rumal saqil al,</l>',
#  '<space quantity="27" unit="chars" /><l>saqil k\'ajol.</l>',
#  '<l>Ta chuxoq!</l>',
#  "<l>Rumal chi naj kopon wi nuwach! Cha' ri Wuqub' Kak'ix.</l>",
#  "<l>Ma k'u qitzij are ta q'ij ri Wuqub' Kak'ix.</l>",
#  "<l>Xere kunimarisaj rib',</l>",
#  '<space quantity="17" unit="chars" /><l>ri uxik\',</l>',
#  '<space quantity="20" unit="chars" /><l>upuwaq.</l>',
#  "<l>Xere k'ut tokol wi uwach ri chi kub'e wi;</l>",
#  "<l>mana ronojel ta uxe' kaj kopon wi uwach.</l>",
#  "<l>Maja k'ut k'i kiloq uwach q'ij,</l>",
#  '<space quantity="26" unit="chars" /><l>ik\',</l>',
#  '<space quantity="26" unit="chars" /><l>ch\'umil,</l>',
#  "<l>maja'oq kasaqiroq.</l>",
#  "<l>K'eje k'ut kukob'isaj wi rib' ri Wuqub' Kak'ix chi q'ijil,</l>",
#  '<space quantity="47" unit="chars" /><l>chi ik\'il.</l>',
#  "<l>Xa maja chi k'utunoq,</l>",
#  "<l>chi q'alajob'oq usaqil q'ij,</l>",
#  '<space quantity="23" unit="chars" /><l>ik\'.</l>',
#  '<l>Xa xurayij nimal,</l>',
#  '<space quantity="16" unit="chars" /><l>ik\'owen.</l>',
#  "<l>Are ta xb'anik b'utik kumal poy</l>",
#  '<space quantity="28" unit="chars" /><l>ajam che\'.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'EJE K'UT XCHIQAB'IJ CHIK TA XKAMIK WUQUB' KAK'IX,</l>",
#  '<lb /> <!-- potential div marker -->',
#  '<l>ta xchakatajik,</l>',
#  "<l>ta xb'anatajik winaq rumal Ajtz'aq,</l>",
#  '<space quantity="27" unit="chars" /><l>Ajb\'it.</l>',
#  "<l>Wa'e uxe' uch'akatajik,</l>",
#  '<space quantity="10" unit="chars" /><l>uyiqoxik chi puch uq\'ij Wuqub\' Kak\'ix kumal ka\'ib\'</l>',
#  "<l>k'ajolab',</l>",
#  "<l>Junajpu ub'i' jun,</l>",
#  "<l>Xb'alanke ub'i' ukab'.</l>",
#  "<l>Xawi e kab'awil.</l>",
#  "<l>Rumal itzel xkilo ri nimarisay rib'</l>",
#  "<l>xraj ub'an chuwach Uk'ux Kaj.</l>",
#  "<l>Xcha' ku ri k'ajolab':</l>",
#  '<l>- Mawi utz ta chuxoq.</l>',
#  "<l>Mawi chik'ase winaq waral chuwach ulew.</l>",
#  "<l>K'eje k'ut chiqatij uwub'axik chuwi recha';</l>",
#  "<l>chiqawub'aj wi chiri',</l>",
#  "<l>chiqakoj wi uyab'!</l>",
#  "<l>Tak'isoq uq'inomal,</l>",
#  '<space quantity="9" unit="chars" /><l>uxit,</l>',
#  '<space quantity="9" unit="chars" /><l>upuwaq,</l>',
#  '<space quantity="9" unit="chars" /><l>uk\'uwal,</l>',
#  '<space quantity="9" unit="chars" /><l>uyamanik ri kuk\'akab\'ej.</l>',
#  "<l>K'eje k'ut chub'ano ronojel winaq,</l>",
#  "<l>mawi are chiwinaqir wi q'aq'al ri xa puwaq.</l>",
#  "<l>Ta chuxoq-. Xecha' ri k'ajolab'</l>",
#  "<l>jujun chi ub' kitelen kikab'ichal.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Are k'u ri Wuqub' Kak'ix e ka'ib' uk'ajol:</l>",
#  "<l>are nab'e al ri Sipakna,</l>",
#  "<l>ukab' al chi k'ut ri Kab'raqan;</l>",
#  "<l>Chimalmat k'ut ub'i' kichuch,</l>",
#  '<space quantity="21" unit="chars" /><l>rixoqil ri Wuqub\' Kak\'ix.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Are k'u ri Sipakna are chi re chaaj ri nimaq juyub':</l>",
#  "<l>ri Chi q'aq',</l>",
#  '<space quantity="3" unit="chars" /><l>Junajpu,</l>',
#  '<space quantity="3" unit="chars" /><l>Pek ul ya\',</l>',
#  '<space quantity="3" unit="chars" /><l>Xkanul,</l>',
#  '<space quantity="3" unit="chars" /><l>Makamob\',</l>',
#  '<space quantity="3" unit="chars" /><l>Julisnab\'. Chucha\'xik ub\'i\' juyub\' xk\'olik ta chisaqirik.</l>',
#  "<l>Xa jun aq'ab' chiwinaqirik rumal Sipakna.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Are ri chi k'u ri Kab'raqan chisilab' juyub' rumal,</l>",
#  "<l>chineb'owik ch'uti juyub',</l>",
#  '<space quantity="12" unit="chars" /><l>nima juyub\' rumal.</l>',
#  "<l>Xawi keje nimarisab'al kib' xkib'ano uk'ajol Wuqub' Kak'ix.</l>",
#  "<l>- In wa', in q'ij! Xcha' Wuqub' Kak'ix.</l>",
#  "<l>- In wa', in b'anol ulew! Xcha' ri Sipakna.</l>",
#  "<l>- In chi k'ut chinkiyow kaj,</l>",
#  '<space quantity="14" unit="chars" /><l>chinwulij ronojel ulew! Xcha\' ri Kab\'raqan.</l>',
#  "<l>Xawi uk'ajol Wuqub' Kak'ix,</l>",
#  "<l>xawi chi ri' xkik'am wi kinimal,</l>",
#  '<space quantity="5" unit="chars" /><l>chi rij kikajaw.</l>',
#  "<l>Are k'ut itzel xkil ri k'ajolab'.</l>",
#  "<l>Maja chib'antajoq qa nab'e chuch,</l>",
#  '<space quantity="18" unit="chars" /><l>qa nab\'e qajaw.</l>',
#  "<l>K'eje k'ut xna'ojix wi kikamik,</l>",
#  '<space quantity="23" unit="chars" /><l>kisachik kumal k\'ajolab\'.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Wa'e k'ute uwub'axik Wuqub' Kak'ix kumal ka'ib' k'ajolab':</l>",
#  "<l>xchiqab'ij kich'akatajik chi kijujunal ri nimarisaj rib'.</l>",
#  "<l>Are ri Wuqub' Kak'ix jun nima che' ri tapa'l,</l>",
#  "<l>are k'u recha' ri Wuqub' Kak'ix.</l>",
#  "<l>Are chu lo ri uwach tapa'l,</l>",
#  "<l>chaqan chuwi che' juta q'ij.</l>",
#  "<l>Xiloma k'ut rechab'al kumal ri Junajpu,</l>",
#  '<space quantity="31" unit="chars" /><l>Xb\'alanke.</l>',
#  "<l>Kik'ak'alen chi k'ut chuxe' che' ri Wuqub' Kak'ix,</l>",
#  "<l>e matzamoj ulo ri ka'ib' k'ajolab' pa xaq che'</l>",
#  "<l>ta xopon k'ut Wuqub' Kak'ix</l>",
#  "<l>taqal chuwi recha' ri tapa'l.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'ate k'ut ta xub'axik kumal ri Junajpu:</l>",
#  "<l>taqal ub'aq' wub' chu kakate',</l>",
#  "<l>churaquj uchi' ta xpe chuwi che'</l>",
#  '<l>taqal chuwach ulew.</l>',
#  "<l>Chimalmat k'ut ri Junajpu,</l>",
#  "<l>anim xb'ek qitzij wi xb'e uchapa';</l>",
#  "<l>k'ate k'ut ta xqupix ula uq'ab' ri Junajpu rumal ri Wuqub' Kak'ix.</l>",
#  "<l>Jusuk' xtzaq uloq</l>",
#  '<space quantity="7" unit="chars" /><l>xmejo u1oq tzam uteleb\';</l>',
#  "<l>ta xutzoqopij chi k'ut Junajpu ri Wuqub' Kak'ix.</l>",
#  "<l>Xawi utz xkib'ano,</l>",
#  "<l>ma nab'e kich'akatajik taj rumal Wuqub' Kak'ix.</l>",
#  "<l>Uk'a'am chi k'ut uq'ab' ri Junajpu rumal ri Wuqub' Kak'ix</l>",
#  "<l>ta xb'e chi rochoch.</l>",
#  "<l>Xa chi k'u ulotem ukakate' xoponik.</l>",
#  "<l>-Naki pa mixk'amow chi la? Xcha' k'u ri Chimalmat, rixoqil Wuqub' Kak'ix.</l>",
#  "<l>-Naki pa ri'?</l>",
#  "<l>Ri e ka'ib' k'axtok' mixikiwub'aj!</l>",
#  "<l>Mixsilib'ataj nukakate' rumal xa kachuywaj e we,</l>",
#  "<l>kaq'oxow chik!</l>",
#  "<l>Mi nab'e mixnuk'am uloq:</l>",
#  "<l>Chuwi q'aq' k'ut chixeke wi,</l>",
#  '<space quantity="17" unit="chars" /><l>chitzayab\' a chuwi q\'aq\',</l>',
#  "<l>ta kulkik'ama' chik qitzij chi e k'axtok'- Xcha' ri Wuqub' Kak'ix.</l>",
#  "<l>Ta xuxekeba' uq'ab' ri Junajpu.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Kina'ojinik chik ri Junajpu,</l>",
#  '<space quantity="20" unit="chars" /><l>\'Xb\'alanke.</l>',
#  "<l>Ta xkib'ij k'ut chi rech jun mama',</l>",
#  "<l>qitzij saq chik rismal wi chi mama';</l>",
#  "<l>jun k'u ati't,</l>",
#  "<l>qitzij kernel ati't chik;</l>",
#  "<l>xa keluq'ukila chik chi rijitaq winaq:</l>",
#  "<l>Saqi Nim Aq ub'i', mama'</l>",
#  "<l>Saqi Nima Tziz k'ut ub'i', ati't.</l>",
#  "<l>Xecha' k'u ri k'ajolab'Â· chi ke ri ati't,</l>",
#  '<space quantity="35" unit="chars" /><l>mama\':</l>',
#  "<l>Kixqachb'ilaj taj,</l>",
#  "<l>chib'etak'ama' qaq'ab' ruk' Wuqub' Kak'ix.</l>",
#  '<l>Xa kojtere chi wij:</l>',
#  "<l>k'i ri qamam ri qachb'ilan,</l>",
#  '<l>kaminaq kichuch,</l>',
#  '<space quantity="8" unit="chars" /><l>kikajaw.</l>',
#  "<l>K'eje k'ut ketere,</l>",
#  '<space quantity="6" unit="chars" /><l>kekotila wi chi qij;</l>',
#  '<l>ta la keqasipaj wi.</l>',
#  "<l>Rumal xa elesan uchicopil eyaj kaqab'ano; kixcha'.</l>",
#  "<l>K'eje k'u ri oj ak'alab' chirilo ri Wuqub' Kak'ix.</l>",
#  "<l>Xawi oj kojyawik ina'oj-. Xecha' ri e ka'ib' k'ajolab'.</l>",
#  "<l>-Utz b'a la! Xecha' k'ut.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'ate k'ut ta xeb'ek,</l>",
#  "<l>tzamal k'u b'i ri Wuqub' Kak'ix,</l>",
#  "<l>chuwach uq'alib'al.</l>",
#  "<l>Ta xe'ik'owik ri ati't,</l>",
#  '<space quantity="17" unit="chars" /><l>mama\',</l>',
#  "<l>ke'etzeyaj k'u ri e ka'ib' k'ajolab' chi kij;</l>",
#  "<l>ta xe'ik'ow chuxe' rochoch ajaw,</l>",
#  "<l>kuraquj k'u uchi' ri Wuqub' Kak'ix rumal we.</l>",
#  "<l>Ta xril k'ut Wuqub' Kak'ix ri mama',</l>",
#  '<space quantity="30" unit="chars" /><l>ati\'t kachb\'ilan kib\':</l>',
#  "<l>-Apa kixpe wi, qamam? Xcha' k'u ri ajaw.</l>",
#  "<l>-Xa oj tzuqub'ey qib', lal ajaw.- Xecha' k'ut.</l>",
#  "<l>-Naki pa itzuqub'al? ma iwalk'wal,</l>",
#  '<space quantity="19" unit="chars" /><l>ri iwachb\'ilan?</l>',
#  "<l>-Maja b'i, lal ajaw, e qamam ri,</l>",
#  "<l>xere na re kaqatoq'ob'aj kiwach</l>",
#  "<l>ri ya'axel ju pir,</l>",
#  '<space quantity="6" unit="chars" /><l>ch\'aqap kaqaya\' chi kech, lal ajaw.- Xecha\' k\'ut ri ati\'t,</l>',
#  '<space quantity="58" unit="chars" /><l>mama\'.</l>',
#  "<l>Kutzin k'u ri ajaw rumal uq'oxom we,</l>",
#  "<l>xa kunimaq wachij chik kach'awik:</l>",
#  "<l>-In ta b'a kanaj chi wech,</l>",
#  "<l>chitoq'ob'aj ta nuwach!</l>",
#  "<l>Naki pa ki chib'ano?</l>",
#  "<l>Naki on ki chikunaj? Xcha' k'ut ajaw.</l>",
#  '<l>-Xa uchikopil eyaj chiqelesaj,</l>',
#  "<l>xa k'u ub'aq uwach chiqakunaj,</l>",
#  "<l>xa b'aq chiqawiqo, lal ajaw.- Xecha' k'ut.</l>",
#  "<l>-Utz b'a la! Chikunaj ta b'a we,</l>",
#  "<l>qitzij kaq'oxowik juta q'ij,</l>",
#  "<l>mawi choq'itajik,</l>",
#  "<l>maja b'i nuwaram rumal ruk' ub'aq nuwach.</l>",
#  "<l>Xa xinki'ub'aj e ka'ib' k'axtok'.</l>",
#  '<l>Ta xtikarik mawi kinechajik rumal.</l>',
#  "<l>K'eje ta k'ut chitoq'ob'aj wi nuwach!</l>",
#  "<l>Xa kachuyub' we je chik ri we.</l>",
#  "<l>-Utz b'a la, lal ajaw:</l>",
#  "<l>chikop b'a kaq'uxuwik.</l>",
#  "<l>Xa chok ik'exel chel ri e la!</l>",
#  "<l>- Ma b'a utz lo chel ri we, rumal xere in ajaw wi:</l>",
#  "<l>nukawub'al ri we,</l>",
#  '<space quantity="11" unit="chars" /><l>ruk\' ub\'aq nuwach.</l>',
#  "<l>Xchikakoj chik na k'ut uk'exel,</l>",
#  "<l>jok'om b'aq xchok chik!</l>",
#  "<l>Are k'ut jok'om b'aq xri xa saqi ixim.</l>",
#  "<l>- Utz b'a la chiwelesaj, chito' uloq - . Xcha' k'ut.</l>",
#  "<l>Ta xel k'u ri re Wuqub' Kak'ix,</l>",
#  "<l>xa saqi ixim uk'exel re xokik.</l>",
#  "<l>Xa chi k'u saq julujuj chi ula ixim pu chi'.</l>",
#  "<l>Jusu k'u xqaj uwach,</l>",
#  '<l>mawi ajaw chik xwachinik.</l>',
#  "<l>Xk'is elik ri re k'uwal rax kawakoj pu chi'.</l>",
#  "<l>Ta xkunax chi k'ut ub'aq uwach Wuqub' Kak'ix,</l>",
#  "<l>ta xcholik ub'aq uwach,</l>",
#  "<l>xk'is elik ri puwaq, mana k'ax taj xuna'o,</l>",
#  '<l>xawi xere kamukunik.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>Ta xk'is k'u elik ri unimarisab'al rib',</l>",
#  "<l>xawi kina'oj ri Junajpu,</l>",
#  '<space quantity="16" unit="chars" /><l>Xb\'alanke.</l>',
#  "<l>Ta xkam k'ut ri Wuqub' Kak'ix.</l>",
#  "<l>ta xuk'am k'ut uq'ab' ri Junajpu.</l>",
#  '<l>Xkam nay puch Chimalmat,</l>',
#  '<space quantity="14" unit="chars" /><l>rixoqil Wuqub\' Kak\'ix.</l>',
#  '<lb /> <!-- potential div marker -->',
#  "<l>K'eje k'ut usachik uq'inomal Wuqub' Kak'ix ri',</l>",
#  "<l>xa ajkun xk'amowik ri k'uwal,</l>",
#  '<space quantity="11" unit="chars" /><l>yamanik,</l>',
#  "<l>xupunab'ej waral chuwach ulew.</l>",
#  "<l>Nawal ati't,</l>",
#  "<l>nawal mama' xb'anowik.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Ta xkik'am k'ut kiq'ab',</l>",
#  '<l>xtikitax ukoq.</l>',
#  '<l>Utz chik xuxik.</l>',
#  "<l>Xa rumal ukamik Wuqub' Kak'ix xkaj,</l>",
#  "<l>keje xkib'ano;</l>",
#  "<l>itzel xkilo nimarisab'al ib' .</l>",
#  "<l>K'ate k'ut xeb'e chik e ka'ib' k'ajolab',</l>",
#  "<l>xa utzij ri Uk'ux Kaj ta xkib'ano.</l>",
#  "<l>Wa'e chi k'ute ub'anoj chik sipakna,</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>WA'E CHI K'UTE UB'ANOJ CHIK SIPAKNA,</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>unab'e k'ajol Wuqub' Kak'ix.</l>",
#  "<l>- In b'anol juyub'! Kacha' ri Sipakna.</l>",
#  "<l>Are k'u ri Sipakna katinik chuchi' ja',</l>",
#  "<l>ta xe'ik'owik omuch' k'ajolab',</l>",
#  "<l>e jur wi che',</l>",
#  "<l>raqan kikab'al;</l>",
#  "<l>omuch' chub'inik,</l>",
#  "<l>ta xkiq'at k'ut jun nima che' uwapalil kikab'al.</l>",
#  "<l>K'ate k'ut xb'e ri Sipakna,</l>",
#  "<l>xopon k'u chila' kuk' ri omuch' k'ajolab':</l>",
#  "<l>- Naki pa kib'ano ix k'ajolab'?</l>",
#  "<l>- Xa che' mawi kaqayako</l>",
#  "<l>-Chiteleb'a'!</l>",
#  '<l>Xchintelej!</l>',
#  '<l>Apa kopon wi?</l>',
#  "<l>Naki pa uchak chi ik'ux?</l>",
#  "<l>-Xa uwapalil qakab'al.-</l>",
#  "<l>Utz b'a la!- Cha' k'ut.</l>",
#  "<l>Ta xujuruj k'ut,</l>",
#  "<l>xuteleb'a k'u aq'anoq chu chi kikab'al omuch' k'ajolab'.</l>",
#  "<l>-Xa ta wi katk'oje quk', at k'ajol!</l>",
#  "<l>k'o pa achuch,</l>",
#  '<space quantity="7" unit="chars" /><l>aqajaw?</l>',
#  "<l>-Maja b'i.- Xcha' k'ut.</l>",
#  "<l>-Kaqach'akimaj ta na b'a la chuweq chuwab'axik chik jun qache',</l>",
#  '<space quantity="47" unit="chars" /><l>raqan qakab\'al.-</l>',
#  "<l>-Utz! Xcha' chi k'ut.</l>",
#  "<l>K'ate k'ut xk'am kina'oj ri omuch' k'ajolab':</l>",
#  "<l>-Are ri ala, japa cha' chiqab'an chi re?</l>",
#  '<l>Chiqakamisaj taj?</l>',
#  "<l>Rumal mawi utz ri kub'ano,</l>",
#  "<l>xa utukel mixuyak ri che'.</l>",
#  "<l>Qak'oto jun nima jul,</l>",
#  "<l>chiri' ta k'ut chiqatzaq wi qajoq pa jul.</l>",
#  "<l>Jak'ama' qaja ulew pa jul. Kojcha' ta chi re.</l>",
#  "<l>Chi are ta k'ut pachal qajoq pa jul,</l>",
#  "<l>ta qatarij qajoq ri nima che'.</l>",
#  "<l>Chiri' ta k'ut chikam wi pa jul.- Xecha' k'ut omuch' k'ajolab'.</l>",
#  '<lb /> <!-- potential div marker -->',
#  "<l>Ta xkik'ot k'ut jun nima jul,</l>",
#  '<l>najt xqajik.</l>',
#  "<l>Ta xkitaq k'ut ri Sipakna:</l>",
#  '<l>-Oj kanij chawech,</l>',
#  "<l>chib'eta ak'oto chik ulew,</l>",
#  "<l>mawi kaqariqo.- Xucha'xik.</l>",
#  "<l>-Utz b'a la! Xcha' k'ut.</l>",
#  "<l>K'ate k'ut xqaj pa jul.</l>",
#  "<l>-Kasik'in uloq ta k'ototajoq ri ulew,</l>",
#  "<l>naj ta chiqajik awumal.- Xucha'xik.</l>",
#  "<l>-We! Xcha' k'ut.</l>",
#  "<l>Ta xutik'ib'a uk'otik jul.</l>",
#  "<l>Xa k'u ujul xuk'oto,</l>",
#  '<space quantity="7" unit="chars" /><l>uk\'olb\'al rib\';</l>',
#  '<l>xretamaj ri ukarnisaxik.</l>',
#  "<l>Ta xuk'ot k'ut jun wi chi jul</l>",
#  "<l>chu tzalanem ukab' jul xuk'oto xkolotaj wi.</l>",
#  "<l>- Kajanik'an pa la? Xuchax k'u qajoq kumal omuch' k'ajolab'.</l>",
#  "<l>- Kinanuk'oto,</l>",
#  "<l>we xkixnusik'ij aqanoq,</l>",
#  "<l>ta chutzinoq uk'ototajik.- Xcha' uloq Sipakna chiri' pa jul.</l>",
#  "<l>Ma k'u are kuk'ot uxe jul ri umuqikil,</l>",
#  ...]

# %% [markdown]
# ## Exporting encoding

# %%
with open ('cpk_test.xml', 'a') as cpk_xml:
    for line in text:
        cpk_xml.write(line + '\n')

# %% [markdown]
# ## lg and l numbers

# %%
colop_tree = et.parse('colop-pk.xml')
namespace = '{http://www.tei-c.org/ns/1.0}'

# %%
root = colop_tree.getroot()

# %%
for child in root.findall(f'./{namespace}text/{namespace}body/'):
    for subchild in child.findall(f'./{namespace}lg'):
        print(subchild.attrib)
# Out:
# {'n': '1', '{http://www.w3.org/XML/1998/namespace}id': 'lg01', 'type': 'seccion'}
